# %%
# %load_ext watermark
import pandas as pd
import numpy as np
from typing import Type, Optional, Callable
from typing import List, Dict, Union, Tuple
from myst_nb import glue

# from review_methods_tests import collect_vitals, find_missing, find_missing_loc_dates
# from review_methods_tests import make_a_summary

import matplotlib.pyplot as plt
import matplotlib as mpl
import matplotlib.colors
from matplotlib.colors import LinearSegmentedColormap, ListedColormap

import setvariables as conf_
import reportclass as r_class

# %% [markdown]
# # Cumulative reports
#
# Cumulative reports display the test statistic of a group of codes between members of a group and the cumulative value for the group. Cumulative reports are visualized with heat maps. A valid `ReportClass` object, a more detailed exmamination of the methods in the report class is availablle in [reportitng](reporting). This section refers to the production of tabular data from the observations at different geographic or administrative boundaries.
#
# The tablular data is destined to be consumed by organizations and administrations responsible for the management or assessment of the quanity of litter in the environment. The granularity of the results are at a minimum the municipal level. The lowest recognized administrative unit.
#
# ```{note}
# The GPT assistant is being trained to accept the following methods and commands as key word arguments. So that different clients have access to a standardized output for tabular data.
# ```
#
# ## A top level description
#
# A short and detailed summary of the report can be created by synthesising three tables from the `ReportClass`.
#
# ```python
# header = a_report.a_short_description
# components = a_report.the_number_of_attributes_in_a_feature('feature_type')
# comp_summary = a_report.summarize_feature_labels(feature='feature_type')
# ```

# %%
# starting data, can be MySQL or NoSQL calls
# the three methods accept Callables, as long
# as the out put is pd.DataFrame
c_l = r_class.language_maps()
surveys = r_class.collect_survey_data_for_report()
codes, beaches, land_cover, land_use, streets, river_intersect_lakes = r_class.collect_env_data_for_report()

survey_data = surveys.merge(beaches['canton'], left_on='slug', right_index=True, validate='many_to_one')

# temporal and geographic boundaries
# user defined input
boundaries = dict(canton='Bern', language='fr', start_date="2015-11-01", end_date="2021-12-31")

# the report_data method takes the boundaries and returns returns the top level of the report
# the language and two data frames from the same date range. w_df includes only the surveys
# that meet the criteria in boundaries, w_di includes all the data from the date range.
top_label, language, w_df, w_di = r_class.report_data(boundaries, survey_data.copy(), beaches, codes)

# the language map is included with the module
a_report = r_class.ReportClass(w_df,boundaries, top_label, 'fr', c_l)

# a summary of the different features and boundaries in a report
a_report.available_features
# Out:
# ['parent_boundary', 'feature_type', 'feature_name', 'city']

# %%
most_common, w_mc = a_report.most_common

header = a_report.a_short_description
glue('header', header, display=False)

components = a_report.the_number_of_attributes_in_a_feature('feature_type')
glue('components', components, display=False)

comp_summary = a_report.summarize_feature_labels(feature='feature_type')
glue('comp_summary', comp_summary, display=False)

# %% [markdown]
# ### Synthesising table data
#
# Calling `a_report.a_short_description`, `a_report.the_number_of_attributes_in_a_feature` and `a_report.summarize_feature_labels` provides the data for a top level description and a comparison of the sample total pcs/m of different attributes or features in the data.
#
# ::::{grid}
# :::{grid-item}
# There were `13'759` objects identified in the period between `2015-11-01` and `2021-12-31` in the `canton` of `Bern`. In total, `196` samples were recorded, `99` on `lakes`, `96` at `rivers` and `1` at `parks`.  The lake samples were recorded from `14` `cities` and `14` for `rivers`. The `alpes` only had `one` representative. The `one` sample from the `alpes` is very close to what would be expected from a `lake` sample. The `rivers` have the `lowest` pcs/m.
# :::
# ::::
#
# ::::{grid}
# :::{grid-item}
# {glue}`header`
# :::
# :::{grid-item}
# {glue}`components`
# :::
#
# :::{grid-item}
# {glue}`comp_summary`
# :::
# ::::
#
#
# ```{note} Defining summary texts
#
# Summary texts can be composed in many different ways. There is a role for LLMs at this part of the report. At the very least helping find other locations that fall within the same values. Providing context to either the geographic or adminstrative boundaries.
#
# The person establishing the report can manage the content creation from the LLM or there can be a shared prompt for all reports.
#
# ```

# %% [markdown]
# ### Feature names
#
# The feature names are the labels for the various subreports that can be generated from the current set of data. The prior example is bielersee. In IQAASL the selection was `{'feature_type':'l'}` for most of the report. The selection `{'feature_type':'r'}` was the last section and `{'feature_type':'p'}` had its own chapter.
#
# ```python
# a_report.features
# ```
# The features property is a dictionary or .json object that contains the key value pairs that describe the data in the report. This includes the sample ids for each survey.

# %%
# the lakes 
my_labels = a_report.feature_labels()
print(my_labels['l']['feature_name'])
# Out:
# ['thunersee' 'bielersee' 'aare' 'brienzersee']

# %%
# in the same way the name of the parks and the cities in those parks can be indentified
print(my_labels['p']['feature_name'])
# Out:
# ['alpes-bernoises']

# %%
# the same for rivers
print(my_labels['r']['feature_name'])
# Out:
# ['aarenidau-buren-kanal' 'aare' 'emme' 'langeten' 'schuss' 'zulg']

# %% [markdown]
# ## Comparing results
#
# Once the the objects of intereste are identified (criteria) they can be compared accross the diferent feature_types and labels.
#
# ```python
# t = a_cumulative_report(w_df[w_df.code.isin(most_common.index)], feature_name='feature_type', object_column='code')
# translated_and_style_for_display(t, a_report.lang_maps[a_report.language], a_report.language, gradient=True)
# ```
# For example the most common objects are found at different densitiies depending on the feature type.

# %%
t= r_class.a_cumulative_report(w_df[w_df.code.isin(most_common.index)], feature_name='feature_type', object_column='code')
r_class.translated_and_style_for_display(t, a_report.lang_maps[a_report.language], a_report.language, gradient=True)
# Out:
# <style type="text/css">
# #T_e698a tr:nth-child(even) {
#   background-color: rgba(139, 69, 19, 0.08);
# }
# #T_e698a tr:nth-child(odd) {
#   background: #FFF;
# }
# #T_e698a tr {
#   font-size: 10px;
# }
# #T_e698a th:nth-child(1) {
#   background-color: #FFF;
#   font-size: 12px;
#   text-align: left;
# }
# #T_e698a td {
#   padding: 4px;
#   font-size: 12px;
# }
# #T_e698a caption {
#   caption-side: bottom;
#   font-size: 1em;
#   text-align: left;
# }
# #T_e698a_row0_col0, #T_e698a_row0_col1, #T_e698a_row0_col2, #T_e698a_row0_col3, #T_e698a_row1_col0, #T_e698a_row1_col2, #T_e698a_row1_col3, #T_e698a_row2_col0, #T_e698a_row2_col1, #T_e698a_row2_col3, #T_e698a_row5_col2, #T_e698a_row5_col3, #T_e698a_row6_col0, #T_e698a_row6_col1, #T_e698a_row6_col2, #T_e698a_row6_col3, #T_e698a_row7_col0, #T_e698a_row7_col1, #T_e698a_row7_col2, #T_e698a_row7_col3, #T_e698a_row8_col0, #T_e698a_row8_col3, #T_e698a_row9_col0, #T_e698a_row9_col2, #T_e698a_row9_col3, #T_e698a_row10_col3 {
#   background-color: rgba(255,255,255, .5);
#   color: black;
# }
# #T_e698a_row1_col1, #T_e698a_row2_col2 {
#   background-color: rgba(249,249,249, .5);
#   color: black;
# }
# #T_e698a_row3_col0, #T_e698a_row9_col1 {
#   background-color: rgba(234,234,234, .5);
#   color: black;
# }
# #T_e698a_row3_col1 {
#   background-color: rgba(222,222,222, .5);
#   color: black;
# }
# #T_e698a_row3_col2 {
#   background-color: rgba(127,39,4, .5);
#   color: black;
# }
# #T_e698a_row3_col3 {
#   background-color: rgba(241,241,241, .5);
#   color: black;
# }
# #T_e698a_row4_col0, #T_e698a_row8_col2 {
#   background-color: rgba(244,244,244, .5);
#   color: black;
# }
# #T_e698a_row4_col1 {
#   background-color: rgba(230,230,230, .5);
#   color: black;
# }
# #T_e698a_row4_col2 {
#   background-color: rgba(243,112,27, .5);
#   color: black;
# }
# #T_e698a_row4_col3 {
#   background-color: rgba(252,252,252, .5);
#   color: black;
# }
# #T_e698a_row5_col0, #T_e698a_row8_col1 {
#   background-color: rgba(247,247,247, .5);
#   color: black;
# }
# #T_e698a_row5_col1 {
#   background-color: rgba(208,208,208, .5);
#   color: black;
# }
# #T_e698a_row10_col0 {
#   background-color: rgba(226,226,226, .5);
#   color: black;
# }
# #T_e698a_row10_col1 {
#   background-color: rgba(92,92,92, .5);
#   color: black;
# }
# #T_e698a_row10_col2 {
#   background-color: rgba(213,213,213, .5);
#   color: black;
# }
# </style>
# <table id="T_e698a">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e698a_level0_col0" class="col_heading level0 col0" >Cumulé</th>
#       <th id="T_e698a_level0_col1" class="col_heading level0 col1" >Lac</th>
#       <th id="T_e698a_level0_col2" class="col_heading level0 col2" >Parc</th>
#       <th id="T_e698a_level0_col3" class="col_heading level0 col3" >Rivière</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e698a_level0_row0" class="row_heading level0 row0" >Autres Textiles</th>
#       <td id="T_e698a_row0_col0" class="data row0 col0" >0,00</td>
#       <td id="T_e698a_row0_col1" class="data row0 col1" >0,00</td>
#       <td id="T_e698a_row0_col2" class="data row0 col2" >0,00</td>
#       <td id="T_e698a_row0_col3" class="data row0 col3" >0,00</td>
#     </tr>
#     <tr>
#       <th id="T_e698a_level0_row1" class="row_heading level0 row1" >Verre Brisé</th>
#       <td id="T_e698a_row1_col0" class="data row1 col0" >0,00</td>
#       <td id="T_e698a_row1_col1" class="data row1 col1" >0,02</td>
#       <td id="T_e698a_row1_col2" class="data row1 col2" >0,00</td>
#       <td id="T_e698a_row1_col3" class="data row1 col3" >0,00</td>
#     </tr>
#     <tr>
#       <th id="T_e698a_level0_row2" class="row_heading level0 row2" >Fragments De Verre Ou De Céramique > 2,5 Cm</th>
#       <td id="T_e698a_row2_col0" class="data row2 col0" >0,00</td>
#       <td id="T_e698a_row2_col1" class="data row2 col1" >0,00</td>
#       <td id="T_e698a_row2_col2" class="data row2 col2" >0,02</td>
#       <td id="T_e698a_row2_col3" class="data row2 col3" >0,00</td>
#     </tr>
#     <tr>
#       <th id="T_e698a_level0_row3" class="row_heading level0 row3" >Mégots Et Filtres À Cigarettes</th>
#       <td id="T_e698a_row3_col0" class="data row3 col0" >0,07</td>
#       <td id="T_e698a_row3_col1" class="data row3 col1" >0,10</td>
#       <td id="T_e698a_row3_col2" class="data row3 col2" >1,25</td>
#       <td id="T_e698a_row3_col3" class="data row3 col3" >0,05</td>
#     </tr>
#     <tr>
#       <th id="T_e698a_level0_row4" class="row_heading level0 row4" >Emballages De Bonbons, De Snacks</th>
#       <td id="T_e698a_row4_col0" class="data row4 col0" >0,04</td>
#       <td id="T_e698a_row4_col1" class="data row4 col1" >0,08</td>
#       <td id="T_e698a_row4_col2" class="data row4 col2" >0,72</td>
#       <td id="T_e698a_row4_col3" class="data row4 col3" >0,01</td>
#     </tr>
#     <tr>
#       <th id="T_e698a_level0_row5" class="row_heading level0 row5" >Bâche, Feuille Plastique Industrielle</th>
#       <td id="T_e698a_row5_col0" class="data row5 col0" >0,03</td>
#       <td id="T_e698a_row5_col1" class="data row5 col1" >0,13</td>
#       <td id="T_e698a_row5_col2" class="data row5 col2" >0,00</td>
#       <td id="T_e698a_row5_col3" class="data row5 col3" >0,00</td>
#     </tr>
#     <tr>
#       <th id="T_e698a_level0_row6" class="row_heading level0 row6" >Mousse De Plastique Pour L'Isolation Thermique</th>
#       <td id="T_e698a_row6_col0" class="data row6 col0" >0,00</td>
#       <td id="T_e698a_row6_col1" class="data row6 col1" >0,00</td>
#       <td id="T_e698a_row6_col2" class="data row6 col2" >0,00</td>
#       <td id="T_e698a_row6_col3" class="data row6 col3" >0,00</td>
#     </tr>
#     <tr>
#       <th id="T_e698a_level0_row7" class="row_heading level0 row7" >Emballage Plastique Non Alimentaire</th>
#       <td id="T_e698a_row7_col0" class="data row7 col0" >0,00</td>
#       <td id="T_e698a_row7_col1" class="data row7 col1" >0,00</td>
#       <td id="T_e698a_row7_col2" class="data row7 col2" >0,00</td>
#       <td id="T_e698a_row7_col3" class="data row7 col3" >0,00</td>
#     </tr>
#     <tr>
#       <th id="T_e698a_level0_row8" class="row_heading level0 row8" >Couvercles En Plastique Bouteille:  G21, G22, G23, G24</th>
#       <td id="T_e698a_row8_col0" class="data row8 col0" >0,00</td>
#       <td id="T_e698a_row8_col1" class="data row8 col1" >0,03</td>
#       <td id="T_e698a_row8_col2" class="data row8 col2" >0,04</td>
#       <td id="T_e698a_row8_col3" class="data row8 col3" >0,00</td>
#     </tr>
#     <tr>
#       <th id="T_e698a_level0_row9" class="row_heading level0 row9" >Fragments De Polystyrène Expansé: G76, G81, G82, G83</th>
#       <td id="T_e698a_row9_col0" class="data row9 col0" >0,00</td>
#       <td id="T_e698a_row9_col1" class="data row9 col1" >0,07</td>
#       <td id="T_e698a_row9_col2" class="data row9 col2" >0,00</td>
#       <td id="T_e698a_row9_col3" class="data row9 col3" >0,00</td>
#     </tr>
#     <tr>
#       <th id="T_e698a_level0_row10" class="row_heading level0 row10" >Fragments De Plastique: G80, G79, G78, G75</th>
#       <td id="T_e698a_row10_col0" class="data row10 col0" >0,09</td>
#       <td id="T_e698a_row10_col1" class="data row10 col1" >0,32</td>
#       <td id="T_e698a_row10_col2" class="data row10 col2" >0,12</td>
#       <td id="T_e698a_row10_col3" class="data row10 col3" >0,00</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### Alternate object groups `groupname`
#
# If the column has other labeled values for object identification it can be used to aggregate results for each sample id. Here we consider `groupname`, there is more than one object in a group. They represent use cases.
#
# ```python
# t = a_cumulative_report(w_df[w_df.code.isin(a_report.most_common.index)], feature_name='feature_type', object_column='groupname')
# translated_and_style_for_display(t, a_report.lang_maps[a_report.language], a_report.language, gradient=True)
# ```
# For example the different use cases are found at different densitiies depending on the feature type.

# %%
t = r_class.a_cumulative_report(w_df, feature_name='feature_type', object_column='groupname')
r_class.translated_and_style_for_display(t, a_report.lang_maps[a_report.language], a_report.language, gradient=True)
# Out:
# <style type="text/css">
# #T_c76ff tr:nth-child(even) {
#   background-color: rgba(139, 69, 19, 0.08);
# }
# #T_c76ff tr:nth-child(odd) {
#   background: #FFF;
# }
# #T_c76ff tr {
#   font-size: 10px;
# }
# #T_c76ff th:nth-child(1) {
#   background-color: #FFF;
#   font-size: 12px;
#   text-align: left;
# }
# #T_c76ff td {
#   padding: 4px;
#   font-size: 12px;
# }
# #T_c76ff caption {
#   caption-side: bottom;
#   font-size: 1em;
#   text-align: left;
# }
# #T_c76ff_row0_col0, #T_c76ff_row4_col0, #T_c76ff_row7_col2, #T_c76ff_row8_col3 {
#   background-color: rgba(238,238,238, .5);
#   color: black;
# }
# #T_c76ff_row0_col1, #T_c76ff_row8_col1 {
#   background-color: rgba(203,203,203, .5);
#   color: black;
# }
# #T_c76ff_row0_col2, #T_c76ff_row3_col0, #T_c76ff_row3_col1, #T_c76ff_row3_col3, #T_c76ff_row4_col2, #T_c76ff_row6_col3, #T_c76ff_row7_col3, #T_c76ff_row9_col3, #T_c76ff_row10_col0, #T_c76ff_row10_col3 {
#   background-color: rgba(255,255,255, .5);
#   color: black;
# }
# #T_c76ff_row0_col3, #T_c76ff_row5_col3, #T_c76ff_row9_col0, #T_c76ff_row9_col2 {
#   background-color: rgba(249,249,249, .5);
#   color: black;
# }
# #T_c76ff_row1_col0, #T_c76ff_row2_col1, #T_c76ff_row3_col2 {
#   background-color: rgba(160,160,160, .5);
#   color: black;
# }
# #T_c76ff_row1_col1 {
#   background-color: rgba(115,115,115, .5);
#   color: black;
# }
# #T_c76ff_row1_col2, #T_c76ff_row8_col2 {
#   background-color: rgba(127,39,4, .5);
#   color: black;
# }
# #T_c76ff_row1_col3 {
#   background-color: rgba(220,220,220, .5);
#   color: black;
# }
# #T_c76ff_row2_col0, #T_c76ff_row8_col0 {
#   background-color: rgba(218,218,218, .5);
#   color: black;
# }
# #T_c76ff_row2_col2, #T_c76ff_row4_col1 {
#   background-color: rgba(234,234,234, .5);
#   color: black;
# }
# #T_c76ff_row2_col3, #T_c76ff_row4_col3 {
#   background-color: rgba(241,241,241, .5);
#   color: black;
# }
# #T_c76ff_row5_col0, #T_c76ff_row5_col1, #T_c76ff_row5_col2, #T_c76ff_row10_col2 {
#   background-color: rgba(244,244,244, .5);
#   color: black;
# }
# #T_c76ff_row6_col0 {
#   background-color: rgba(226,226,226, .5);
#   color: black;
# }
# #T_c76ff_row6_col1 {
#   background-color: rgba(92,92,92, .5);
#   color: black;
# }
# #T_c76ff_row6_col2 {
#   background-color: rgba(213,213,213, .5);
#   color: black;
# }
# #T_c76ff_row7_col0 {
#   background-color: rgba(243,243,243, .5);
#   color: black;
# }
# #T_c76ff_row7_col1 {
#   background-color: rgba(222,222,222, .5);
#   color: black;
# }
# #T_c76ff_row9_col1, #T_c76ff_row10_col1 {
#   background-color: rgba(247,247,247, .5);
#   color: black;
# }
# </style>
# <table id="T_c76ff">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c76ff_level0_col0" class="col_heading level0 col0" >Cumulé</th>
#       <th id="T_c76ff_level0_col1" class="col_heading level0 col1" >Lac</th>
#       <th id="T_c76ff_level0_col2" class="col_heading level0 col2" >Parc</th>
#       <th id="T_c76ff_level0_col3" class="col_heading level0 col3" >Rivière</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c76ff_level0_row0" class="row_heading level0 row0" >Agriculture</th>
#       <td id="T_c76ff_row0_col0" class="data row0 col0" >0,06</td>
#       <td id="T_c76ff_row0_col1" class="data row0 col1" >0,14</td>
#       <td id="T_c76ff_row0_col2" class="data row0 col2" >0,00</td>
#       <td id="T_c76ff_row0_col3" class="data row0 col3" >0,02</td>
#     </tr>
#     <tr>
#       <th id="T_c76ff_level0_row1" class="row_heading level0 row1" >Nourriture Et Boissons</th>
#       <td id="T_c76ff_row1_col0" class="data row1 col0" >0,21</td>
#       <td id="T_c76ff_row1_col1" class="data row1 col1" >0,28</td>
#       <td id="T_c76ff_row1_col2" class="data row1 col2" >0,95</td>
#       <td id="T_c76ff_row1_col3" class="data row1 col3" >0,11</td>
#     </tr>
#     <tr>
#       <th id="T_c76ff_level0_row2" class="row_heading level0 row2" >Infrastructures</th>
#       <td id="T_c76ff_row2_col0" class="data row2 col0" >0,11</td>
#       <td id="T_c76ff_row2_col1" class="data row2 col1" >0,21</td>
#       <td id="T_c76ff_row2_col2" class="data row2 col2" >0,07</td>
#       <td id="T_c76ff_row2_col3" class="data row2 col3" >0,05</td>
#     </tr>
#     <tr>
#       <th id="T_c76ff_level0_row3" class="row_heading level0 row3" >Micro-Plastiques (< 5Mm)</th>
#       <td id="T_c76ff_row3_col0" class="data row3 col0" >0,00</td>
#       <td id="T_c76ff_row3_col1" class="data row3 col1" >0,00</td>
#       <td id="T_c76ff_row3_col2" class="data row3 col2" >0,21</td>
#       <td id="T_c76ff_row3_col3" class="data row3 col3" >0,00</td>
#     </tr>
#     <tr>
#       <th id="T_c76ff_level0_row4" class="row_heading level0 row4" >Emballage Non Alimentaire</th>
#       <td id="T_c76ff_row4_col0" class="data row4 col0" >0,06</td>
#       <td id="T_c76ff_row4_col1" class="data row4 col1" >0,07</td>
#       <td id="T_c76ff_row4_col2" class="data row4 col2" >0,00</td>
#       <td id="T_c76ff_row4_col3" class="data row4 col3" >0,05</td>
#     </tr>
#     <tr>
#       <th id="T_c76ff_level0_row5" class="row_heading level0 row5" >Articles Personnels</th>
#       <td id="T_c76ff_row5_col0" class="data row5 col0" >0,04</td>
#       <td id="T_c76ff_row5_col1" class="data row5 col1" >0,04</td>
#       <td id="T_c76ff_row5_col2" class="data row5 col2" >0,04</td>
#       <td id="T_c76ff_row5_col3" class="data row5 col3" >0,02</td>
#     </tr>
#     <tr>
#       <th id="T_c76ff_level0_row6" class="row_heading level0 row6" >Morceaux De Plastique</th>
#       <td id="T_c76ff_row6_col0" class="data row6 col0" >0,09</td>
#       <td id="T_c76ff_row6_col1" class="data row6 col1" >0,32</td>
#       <td id="T_c76ff_row6_col2" class="data row6 col2" >0,12</td>
#       <td id="T_c76ff_row6_col3" class="data row6 col3" >0,00</td>
#     </tr>
#     <tr>
#       <th id="T_c76ff_level0_row7" class="row_heading level0 row7" >Loisirs</th>
#       <td id="T_c76ff_row7_col0" class="data row7 col0" >0,04</td>
#       <td id="T_c76ff_row7_col1" class="data row7 col1" >0,10</td>
#       <td id="T_c76ff_row7_col2" class="data row7 col2" >0,06</td>
#       <td id="T_c76ff_row7_col3" class="data row7 col3" >0,00</td>
#     </tr>
#     <tr>
#       <th id="T_c76ff_level0_row8" class="row_heading level0 row8" >Tabac</th>
#       <td id="T_c76ff_row8_col0" class="data row8 col0" >0,11</td>
#       <td id="T_c76ff_row8_col1" class="data row8 col1" >0,14</td>
#       <td id="T_c76ff_row8_col2" class="data row8 col2" >1,30</td>
#       <td id="T_c76ff_row8_col3" class="data row8 col3" >0,06</td>
#     </tr>
#     <tr>
#       <th id="T_c76ff_level0_row9" class="row_heading level0 row9" >Non Classé</th>
#       <td id="T_c76ff_row9_col0" class="data row9 col0" >0,02</td>
#       <td id="T_c76ff_row9_col1" class="data row9 col1" >0,03</td>
#       <td id="T_c76ff_row9_col2" class="data row9 col2" >0,02</td>
#       <td id="T_c76ff_row9_col3" class="data row9 col3" >0,00</td>
#     </tr>
#     <tr>
#       <th id="T_c76ff_level0_row10" class="row_heading level0 row10" >Eaux Usées</th>
#       <td id="T_c76ff_row10_col0" class="data row10 col0" >0,00</td>
#       <td id="T_c76ff_row10_col1" class="data row10 col1" >0,03</td>
#       <td id="T_c76ff_row10_col2" class="data row10 col2" >0,04</td>
#       <td id="T_c76ff_row10_col3" class="data row10 col3" >0,00</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### By Survey area or `parent_boundary`
#
# There are two parent boundaries in the Valais, the _Alpes and Jura_ and the _Rhône_ river basin.

# %%
t = r_class.a_cumulative_report(w_df[w_df.code.isin(most_common.index)], feature_name='parent_boundary', object_column='code')

r_class.translated_and_style_for_display(t,a_report.lang_maps[a_report.language], a_report.language, gradient=True)
# Out:
# <style type="text/css">
# #T_01b69 tr:nth-child(even) {
#   background-color: rgba(139, 69, 19, 0.08);
# }
# #T_01b69 tr:nth-child(odd) {
#   background: #FFF;
# }
# #T_01b69 tr {
#   font-size: 10px;
# }
# #T_01b69 th:nth-child(1) {
#   background-color: #FFF;
#   font-size: 12px;
#   text-align: left;
# }
# #T_01b69 td {
#   padding: 4px;
#   font-size: 12px;
# }
# #T_01b69 caption {
#   caption-side: bottom;
#   font-size: 1em;
#   text-align: left;
# }
# #T_01b69_row0_col0, #T_01b69_row0_col1, #T_01b69_row0_col2, #T_01b69_row1_col0, #T_01b69_row1_col1, #T_01b69_row1_col2, #T_01b69_row2_col0, #T_01b69_row2_col1, #T_01b69_row5_col2, #T_01b69_row6_col0, #T_01b69_row6_col1, #T_01b69_row6_col2, #T_01b69_row7_col0, #T_01b69_row7_col1, #T_01b69_row7_col2, #T_01b69_row8_col0, #T_01b69_row8_col1, #T_01b69_row9_col0, #T_01b69_row9_col1, #T_01b69_row9_col2 {
#   background-color: rgba(255,255,255, .5);
#   color: black;
# }
# #T_01b69_row2_col2 {
#   background-color: rgba(249,249,249, .5);
#   color: black;
# }
# #T_01b69_row3_col0, #T_01b69_row3_col1 {
#   background-color: rgba(234,234,234, .5);
#   color: black;
# }
# #T_01b69_row3_col2 {
#   background-color: rgba(127,39,4, .5);
#   color: black;
# }
# #T_01b69_row4_col0, #T_01b69_row4_col1, #T_01b69_row8_col2 {
#   background-color: rgba(244,244,244, .5);
#   color: black;
# }
# #T_01b69_row4_col2 {
#   background-color: rgba(243,112,27, .5);
#   color: black;
# }
# #T_01b69_row5_col0, #T_01b69_row5_col1 {
#   background-color: rgba(247,247,247, .5);
#   color: black;
# }
# #T_01b69_row10_col0, #T_01b69_row10_col1 {
#   background-color: rgba(226,226,226, .5);
#   color: black;
# }
# #T_01b69_row10_col2 {
#   background-color: rgba(213,213,213, .5);
#   color: black;
# }
# </style>
# <table id="T_01b69">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_01b69_level0_col0" class="col_heading level0 col0" >Aare</th>
#       <th id="T_01b69_level0_col1" class="col_heading level0 col1" >Cumulé</th>
#       <th id="T_01b69_level0_col2" class="col_heading level0 col2" >Alpes Et Jura</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_01b69_level0_row0" class="row_heading level0 row0" >Autres Textiles</th>
#       <td id="T_01b69_row0_col0" class="data row0 col0" >0,00</td>
#       <td id="T_01b69_row0_col1" class="data row0 col1" >0,00</td>
#       <td id="T_01b69_row0_col2" class="data row0 col2" >0,00</td>
#     </tr>
#     <tr>
#       <th id="T_01b69_level0_row1" class="row_heading level0 row1" >Verre Brisé</th>
#       <td id="T_01b69_row1_col0" class="data row1 col0" >0,00</td>
#       <td id="T_01b69_row1_col1" class="data row1 col1" >0,00</td>
#       <td id="T_01b69_row1_col2" class="data row1 col2" >0,00</td>
#     </tr>
#     <tr>
#       <th id="T_01b69_level0_row2" class="row_heading level0 row2" >Fragments De Verre Ou De Céramique > 2,5 Cm</th>
#       <td id="T_01b69_row2_col0" class="data row2 col0" >0,00</td>
#       <td id="T_01b69_row2_col1" class="data row2 col1" >0,00</td>
#       <td id="T_01b69_row2_col2" class="data row2 col2" >0,02</td>
#     </tr>
#     <tr>
#       <th id="T_01b69_level0_row3" class="row_heading level0 row3" >Mégots Et Filtres À Cigarettes</th>
#       <td id="T_01b69_row3_col0" class="data row3 col0" >0,07</td>
#       <td id="T_01b69_row3_col1" class="data row3 col1" >0,07</td>
#       <td id="T_01b69_row3_col2" class="data row3 col2" >1,25</td>
#     </tr>
#     <tr>
#       <th id="T_01b69_level0_row4" class="row_heading level0 row4" >Emballages De Bonbons, De Snacks</th>
#       <td id="T_01b69_row4_col0" class="data row4 col0" >0,04</td>
#       <td id="T_01b69_row4_col1" class="data row4 col1" >0,04</td>
#       <td id="T_01b69_row4_col2" class="data row4 col2" >0,72</td>
#     </tr>
#     <tr>
#       <th id="T_01b69_level0_row5" class="row_heading level0 row5" >Bâche, Feuille Plastique Industrielle</th>
#       <td id="T_01b69_row5_col0" class="data row5 col0" >0,03</td>
#       <td id="T_01b69_row5_col1" class="data row5 col1" >0,03</td>
#       <td id="T_01b69_row5_col2" class="data row5 col2" >0,00</td>
#     </tr>
#     <tr>
#       <th id="T_01b69_level0_row6" class="row_heading level0 row6" >Mousse De Plastique Pour L'Isolation Thermique</th>
#       <td id="T_01b69_row6_col0" class="data row6 col0" >0,00</td>
#       <td id="T_01b69_row6_col1" class="data row6 col1" >0,00</td>
#       <td id="T_01b69_row6_col2" class="data row6 col2" >0,00</td>
#     </tr>
#     <tr>
#       <th id="T_01b69_level0_row7" class="row_heading level0 row7" >Emballage Plastique Non Alimentaire</th>
#       <td id="T_01b69_row7_col0" class="data row7 col0" >0,00</td>
#       <td id="T_01b69_row7_col1" class="data row7 col1" >0,00</td>
#       <td id="T_01b69_row7_col2" class="data row7 col2" >0,00</td>
#     </tr>
#     <tr>
#       <th id="T_01b69_level0_row8" class="row_heading level0 row8" >Couvercles En Plastique Bouteille:  G21, G22, G23, G24</th>
#       <td id="T_01b69_row8_col0" class="data row8 col0" >0,00</td>
#       <td id="T_01b69_row8_col1" class="data row8 col1" >0,00</td>
#       <td id="T_01b69_row8_col2" class="data row8 col2" >0,04</td>
#     </tr>
#     <tr>
#       <th id="T_01b69_level0_row9" class="row_heading level0 row9" >Fragments De Polystyrène Expansé: G76, G81, G82, G83</th>
#       <td id="T_01b69_row9_col0" class="data row9 col0" >0,00</td>
#       <td id="T_01b69_row9_col1" class="data row9 col1" >0,00</td>
#       <td id="T_01b69_row9_col2" class="data row9 col2" >0,00</td>
#     </tr>
#     <tr>
#       <th id="T_01b69_level0_row10" class="row_heading level0 row10" >Fragments De Plastique: G80, G79, G78, G75</th>
#       <td id="T_01b69_row10_col0" class="data row10 col0" >0,09</td>
#       <td id="T_01b69_row10_col1" class="data row10 col1" >0,09</td>
#       <td id="T_01b69_row10_col2" class="data row10 col2" >0,12</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### By `feature_name`:
#
# There are three different features with samples: Tha Alpes, the Rhône river and Lake Geneva.

# %%
t = r_class.a_cumulative_report(w_df[w_df.code.isin(most_common.index)], feature_name='feature_name', object_column='code')
r_class.translated_and_style_for_display(t, a_report.lang_maps[a_report.language], a_report.language, gradient=True)
# Out:
# <style type="text/css">
# #T_6bbf3 tr:nth-child(even) {
#   background-color: rgba(139, 69, 19, 0.08);
# }
# #T_6bbf3 tr:nth-child(odd) {
#   background: #FFF;
# }
# #T_6bbf3 tr {
#   font-size: 10px;
# }
# #T_6bbf3 th:nth-child(1) {
#   background-color: #FFF;
#   font-size: 12px;
#   text-align: left;
# }
# #T_6bbf3 td {
#   padding: 4px;
#   font-size: 12px;
# }
# #T_6bbf3 caption {
#   caption-side: bottom;
#   font-size: 1em;
#   text-align: left;
# }
# #T_6bbf3_row0_col0, #T_6bbf3_row0_col1, #T_6bbf3_row0_col2, #T_6bbf3_row0_col3, #T_6bbf3_row0_col4, #T_6bbf3_row0_col5, #T_6bbf3_row0_col6, #T_6bbf3_row0_col7, #T_6bbf3_row0_col8, #T_6bbf3_row0_col9, #T_6bbf3_row0_col10, #T_6bbf3_row1_col0, #T_6bbf3_row1_col2, #T_6bbf3_row1_col3, #T_6bbf3_row1_col5, #T_6bbf3_row1_col6, #T_6bbf3_row1_col7, #T_6bbf3_row1_col10, #T_6bbf3_row2_col0, #T_6bbf3_row2_col1, #T_6bbf3_row2_col2, #T_6bbf3_row2_col4, #T_6bbf3_row2_col5, #T_6bbf3_row2_col6, #T_6bbf3_row2_col8, #T_6bbf3_row2_col9, #T_6bbf3_row2_col10, #T_6bbf3_row3_col10, #T_6bbf3_row4_col0, #T_6bbf3_row4_col6, #T_6bbf3_row5_col1, #T_6bbf3_row5_col3, #T_6bbf3_row5_col6, #T_6bbf3_row5_col7, #T_6bbf3_row5_col8, #T_6bbf3_row5_col10, #T_6bbf3_row6_col0, #T_6bbf3_row6_col1, #T_6bbf3_row6_col2, #T_6bbf3_row6_col3, #T_6bbf3_row6_col4, #T_6bbf3_row6_col6, #T_6bbf3_row6_col7, #T_6bbf3_row6_col8, #T_6bbf3_row6_col9, #T_6bbf3_row6_col10, #T_6bbf3_row7_col0, #T_6bbf3_row7_col1, #T_6bbf3_row7_col2, #T_6bbf3_row7_col3, #T_6bbf3_row7_col4, #T_6bbf3_row7_col5, #T_6bbf3_row7_col6, #T_6bbf3_row7_col7, #T_6bbf3_row7_col9, #T_6bbf3_row7_col10, #T_6bbf3_row8_col0, #T_6bbf3_row8_col1, #T_6bbf3_row8_col2, #T_6bbf3_row8_col6, #T_6bbf3_row8_col7, #T_6bbf3_row8_col9, #T_6bbf3_row8_col10, #T_6bbf3_row9_col0, #T_6bbf3_row9_col1, #T_6bbf3_row9_col2, #T_6bbf3_row9_col3, #T_6bbf3_row9_col6, #T_6bbf3_row9_col7, #T_6bbf3_row9_col8, #T_6bbf3_row9_col10, #T_6bbf3_row10_col0, #T_6bbf3_row10_col6, #T_6bbf3_row10_col10 {
#   background-color: rgba(255,255,255, .5);
#   color: black;
# }
# #T_6bbf3_row1_col1, #T_6bbf3_row3_col0, #T_6bbf3_row4_col9, #T_6bbf3_row5_col2, #T_6bbf3_row7_col8 {
#   background-color: rgba(247,247,247, .5);
#   color: black;
# }
# #T_6bbf3_row1_col4, #T_6bbf3_row1_col9, #T_6bbf3_row2_col3 {
#   background-color: rgba(249,249,249, .5);
#   color: black;
# }
# #T_6bbf3_row1_col8, #T_6bbf3_row9_col5 {
#   background-color: rgba(198,198,198, .5);
#   color: black;
# }
# #T_6bbf3_row2_col7, #T_6bbf3_row10_col7 {
#   background-color: rgba(109,109,109, .5);
#   color: black;
# }
# #T_6bbf3_row3_col1 {
#   background-color: rgba(115,115,115, .5);
#   color: black;
# }
# #T_6bbf3_row3_col2, #T_6bbf3_row3_col7, #T_6bbf3_row4_col7 {
#   background-color: rgba(234,234,234, .5);
#   color: black;
# }
# #T_6bbf3_row3_col3 {
#   background-color: rgba(127,39,4, .5);
#   color: black;
# }
# #T_6bbf3_row3_col4, #T_6bbf3_row3_col5, #T_6bbf3_row4_col10, #T_6bbf3_row8_col4, #T_6bbf3_row10_col8 {
#   background-color: rgba(238,238,238, .5);
#   color: black;
# }
# #T_6bbf3_row3_col6, #T_6bbf3_row8_col5, #T_6bbf3_row10_col9 {
#   background-color: rgba(218,218,218, .5);
#   color: black;
# }
# #T_6bbf3_row3_col8, #T_6bbf3_row4_col5 {
#   background-color: rgba(121,121,121, .5);
#   color: black;
# }
# #T_6bbf3_row3_col9 {
#   background-color: rgba(203,203,203, .5);
#   color: black;
# }
# #T_6bbf3_row4_col1, #T_6bbf3_row5_col0, #T_6bbf3_row8_col8 {
#   background-color: rgba(252,252,252, .5);
#   color: black;
# }
# #T_6bbf3_row4_col2, #T_6bbf3_row5_col9, #T_6bbf3_row8_col3, #T_6bbf3_row10_col1 {
#   background-color: rgba(244,244,244, .5);
#   color: black;
# }
# #T_6bbf3_row4_col3 {
#   background-color: rgba(243,112,27, .5);
#   color: black;
# }
# #T_6bbf3_row4_col4 {
#   background-color: rgba(193,193,193, .5);
#   color: black;
# }
# #T_6bbf3_row4_col8 {
#   background-color: rgba(228,228,228, .5);
#   color: black;
# }
# #T_6bbf3_row5_col4 {
#   background-color: rgba(103,103,103, .5);
#   color: black;
# }
# #T_6bbf3_row5_col5 {
#   background-color: rgba(254,239,224, .5);
#   color: black;
# }
# #T_6bbf3_row6_col5, #T_6bbf3_row9_col4 {
#   background-color: rgba(241,241,241, .5);
#   color: black;
# }
# #T_6bbf3_row9_col9 {
#   background-color: rgba(230,230,230, .5);
#   color: black;
# }
# #T_6bbf3_row10_col2 {
#   background-color: rgba(226,226,226, .5);
#   color: black;
# }
# #T_6bbf3_row10_col3 {
#   background-color: rgba(213,213,213, .5);
#   color: black;
# }
# #T_6bbf3_row10_col4 {
#   background-color: rgba(253,173,105, .5);
#   color: black;
# }
# #T_6bbf3_row10_col5 {
#   background-color: rgba(253,220,187, .5);
#   color: black;
# }
# </style>
# <table id="T_6bbf3">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6bbf3_level0_col0" class="col_heading level0 col0" >Aare</th>
#       <th id="T_6bbf3_level0_col1" class="col_heading level0 col1" >Aarenidau-Buren-Kanal</th>
#       <th id="T_6bbf3_level0_col2" class="col_heading level0 col2" >Cumulé</th>
#       <th id="T_6bbf3_level0_col3" class="col_heading level0 col3" >Alpes-Bernoises</th>
#       <th id="T_6bbf3_level0_col4" class="col_heading level0 col4" >Bielersee</th>
#       <th id="T_6bbf3_level0_col5" class="col_heading level0 col5" >Brienzersee</th>
#       <th id="T_6bbf3_level0_col6" class="col_heading level0 col6" >Emme</th>
#       <th id="T_6bbf3_level0_col7" class="col_heading level0 col7" >Langeten</th>
#       <th id="T_6bbf3_level0_col8" class="col_heading level0 col8" >Schuss</th>
#       <th id="T_6bbf3_level0_col9" class="col_heading level0 col9" >Thunersee</th>
#       <th id="T_6bbf3_level0_col10" class="col_heading level0 col10" >Zulg</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6bbf3_level0_row0" class="row_heading level0 row0" >Autres Textiles</th>
#       <td id="T_6bbf3_row0_col0" class="data row0 col0" >0,00</td>
#       <td id="T_6bbf3_row0_col1" class="data row0 col1" >0,00</td>
#       <td id="T_6bbf3_row0_col2" class="data row0 col2" >0,00</td>
#       <td id="T_6bbf3_row0_col3" class="data row0 col3" >0,00</td>
#       <td id="T_6bbf3_row0_col4" class="data row0 col4" >0,00</td>
#       <td id="T_6bbf3_row0_col5" class="data row0 col5" >0,00</td>
#       <td id="T_6bbf3_row0_col6" class="data row0 col6" >0,00</td>
#       <td id="T_6bbf3_row0_col7" class="data row0 col7" >0,00</td>
#       <td id="T_6bbf3_row0_col8" class="data row0 col8" >0,00</td>
#       <td id="T_6bbf3_row0_col9" class="data row0 col9" >0,00</td>
#       <td id="T_6bbf3_row0_col10" class="data row0 col10" >0,00</td>
#     </tr>
#     <tr>
#       <th id="T_6bbf3_level0_row1" class="row_heading level0 row1" >Verre Brisé</th>
#       <td id="T_6bbf3_row1_col0" class="data row1 col0" >0,00</td>
#       <td id="T_6bbf3_row1_col1" class="data row1 col1" >0,03</td>
#       <td id="T_6bbf3_row1_col2" class="data row1 col2" >0,00</td>
#       <td id="T_6bbf3_row1_col3" class="data row1 col3" >0,00</td>
#       <td id="T_6bbf3_row1_col4" class="data row1 col4" >0,02</td>
#       <td id="T_6bbf3_row1_col5" class="data row1 col5" >0,00</td>
#       <td id="T_6bbf3_row1_col6" class="data row1 col6" >0,00</td>
#       <td id="T_6bbf3_row1_col7" class="data row1 col7" >0,00</td>
#       <td id="T_6bbf3_row1_col8" class="data row1 col8" >0,15</td>
#       <td id="T_6bbf3_row1_col9" class="data row1 col9" >0,02</td>
#       <td id="T_6bbf3_row1_col10" class="data row1 col10" >0,00</td>
#     </tr>
#     <tr>
#       <th id="T_6bbf3_level0_row2" class="row_heading level0 row2" >Fragments De Verre Ou De Céramique > 2,5 Cm</th>
#       <td id="T_6bbf3_row2_col0" class="data row2 col0" >0,00</td>
#       <td id="T_6bbf3_row2_col1" class="data row2 col1" >0,00</td>
#       <td id="T_6bbf3_row2_col2" class="data row2 col2" >0,00</td>
#       <td id="T_6bbf3_row2_col3" class="data row2 col3" >0,02</td>
#       <td id="T_6bbf3_row2_col4" class="data row2 col4" >0,00</td>
#       <td id="T_6bbf3_row2_col5" class="data row2 col5" >0,00</td>
#       <td id="T_6bbf3_row2_col6" class="data row2 col6" >0,00</td>
#       <td id="T_6bbf3_row2_col7" class="data row2 col7" >0,29</td>
#       <td id="T_6bbf3_row2_col8" class="data row2 col8" >0,00</td>
#       <td id="T_6bbf3_row2_col9" class="data row2 col9" >0,00</td>
#       <td id="T_6bbf3_row2_col10" class="data row2 col10" >0,00</td>
#     <

# %% [markdown]
# ### By `city`:

# %%
t = r_class.a_cumulative_report(w_df[w_df.code.isin(most_common.index)], feature_name='city', object_column='code')
r_class.translated_and_style_for_display(t, a_report.lang_maps[a_report.language], a_report.language, gradient=True)
# Out:
# <style type="text/css">
# #T_0ff15 tr:nth-child(even) {
#   background-color: rgba(139, 69, 19, 0.08);
# }
# #T_0ff15 tr:nth-child(odd) {
#   background: #FFF;
# }
# #T_0ff15 tr {
#   font-size: 10px;
# }
# #T_0ff15 th:nth-child(1) {
#   background-color: #FFF;
#   font-size: 12px;
#   text-align: left;
# }
# #T_0ff15 td {
#   padding: 4px;
#   font-size: 12px;
# }
# #T_0ff15 caption {
#   caption-side: bottom;
#   font-size: 1em;
#   text-align: left;
# }
# #T_0ff15_row0_col0, #T_0ff15_row0_col1, #T_0ff15_row0_col2, #T_0ff15_row0_col3, #T_0ff15_row0_col4, #T_0ff15_row0_col5, #T_0ff15_row0_col7, #T_0ff15_row0_col8, #T_0ff15_row0_col9, #T_0ff15_row0_col10, #T_0ff15_row0_col11, #T_0ff15_row0_col12, #T_0ff15_row0_col13, #T_0ff15_row0_col14, #T_0ff15_row0_col15, #T_0ff15_row0_col17, #T_0ff15_row0_col18, #T_0ff15_row0_col19, #T_0ff15_row0_col20, #T_0ff15_row0_col21, #T_0ff15_row0_col22, #T_0ff15_row0_col23, #T_0ff15_row0_col24, #T_0ff15_row0_col25, #T_0ff15_row0_col26, #T_0ff15_row0_col27, #T_0ff15_row1_col1, #T_0ff15_row1_col2, #T_0ff15_row1_col4, #T_0ff15_row1_col6, #T_0ff15_row1_col7, #T_0ff15_row1_col10, #T_0ff15_row1_col11, #T_0ff15_row1_col12, #T_0ff15_row1_col13, #T_0ff15_row1_col16, #T_0ff15_row1_col19, #T_0ff15_row1_col20, #T_0ff15_row1_col21, #T_0ff15_row1_col22, #T_0ff15_row1_col24, #T_0ff15_row1_col25, #T_0ff15_row1_col26, #T_0ff15_row1_col27, #T_0ff15_row2_col0, #T_0ff15_row2_col1, #T_0ff15_row2_col2, #T_0ff15_row2_col3, #T_0ff15_row2_col4, #T_0ff15_row2_col5, #T_0ff15_row2_col6, #T_0ff15_row2_col7, #T_0ff15_row2_col8, #T_0ff15_row2_col9, #T_0ff15_row2_col11, #T_0ff15_row2_col14, #T_0ff15_row2_col15, #T_0ff15_row2_col17, #T_0ff15_row2_col18, #T_0ff15_row2_col19, #T_0ff15_row2_col21, #T_0ff15_row2_col22, #T_0ff15_row2_col23, #T_0ff15_row2_col24, #T_0ff15_row2_col25, #T_0ff15_row2_col26, #T_0ff15_row2_col27, #T_0ff15_row3_col1, #T_0ff15_row3_col4, #T_0ff15_row3_col11, #T_0ff15_row3_col17, #T_0ff15_row3_col21, #T_0ff15_row3_col26, #T_0ff15_row4_col1, #T_0ff15_row4_col2, #T_0ff15_row4_col5, #T_0ff15_row4_col20, #T_0ff15_row4_col24, #T_0ff15_row4_col26, #T_0ff15_row5_col5, #T_0ff15_row5_col8, #T_0ff15_row5_col10, #T_0ff15_row5_col12, #T_0ff15_row5_col13, #T_0ff15_row5_col16, #T_0ff15_row5_col18, #T_0ff15_row5_col19, #T_0ff15_row5_col20, #T_0ff15_row5_col21, #T_0ff15_row5_col24, #T_0ff15_row5_col26, #T_0ff15_row6_col1, #T_0ff15_row6_col2, #T_0ff15_row6_col5, #T_0ff15_row6_col6, #T_0ff15_row6_col8, #T_0ff15_row6_col9, #T_0ff15_row6_col10, #T_0ff15_row6_col11, #T_0ff15_row6_col12, #T_0ff15_row6_col13, #T_0ff15_row6_col15, #T_0ff15_row6_col16, #T_0ff15_row6_col17, #T_0ff15_row6_col19, #T_0ff15_row6_col20, #T_0ff15_row6_col21, #T_0ff15_row6_col22, #T_0ff15_row6_col24, #T_0ff15_row6_col25, #T_0ff15_row6_col27, #T_0ff15_row7_col1, #T_0ff15_row7_col2, #T_0ff15_row7_col5, #T_0ff15_row7_col7, #T_0ff15_row7_col9, #T_0ff15_row7_col10, #T_0ff15_row7_col12, #T_0ff15_row7_col13, #T_0ff15_row7_col15, #T_0ff15_row7_col16, #T_0ff15_row7_col19, #T_0ff15_row7_col20, #T_0ff15_row7_col21, #T_0ff15_row7_col22, #T_0ff15_row7_col24, #T_0ff15_row7_col25, #T_0ff15_row7_col26, #T_0ff15_row7_col27, #T_0ff15_row8_col1, #T_0ff15_row8_col2, #T_0ff15_row8_col5, #T_0ff15_row8_col6, #T_0ff15_row8_col9, #T_0ff15_row8_col12, #T_0ff15_row8_col13, #T_0ff15_row8_col14, #T_0ff15_row8_col15, #T_0ff15_row8_col20, #T_0ff15_row8_col21, #T_0ff15_row8_col24, #T_0ff15_row8_col27, #T_0ff15_row9_col1, #T_0ff15_row9_col2, #T_0ff15_row9_col5, #T_0ff15_row9_col6, #T_0ff15_row9_col9, #T_0ff15_row9_col10, #T_0ff15_row9_col12, #T_0ff15_row9_col13, #T_0ff15_row9_col14, #T_0ff15_row9_col15, #T_0ff15_row9_col16, #T_0ff15_row9_col18, #T_0ff15_row9_col19, #T_0ff15_row9_col21, #T_0ff15_row9_col24, #T_0ff15_row9_col26, #T_0ff15_row9_col27, #T_0ff15_row10_col1, #T_0ff15_row10_col19, #T_0ff15_row10_col21, #T_0ff15_row10_col24, #T_0ff15_row10_col26 {
#   background-color: rgba(255,255,255, .5);
#   color: black;
# }
# #T_0ff15_row0_col6, #T_0ff15_row0_col16, #T_0ff15_row3_col15, #T_0ff15_row3_col25, #T_0ff15_row4_col27, #T_0ff15_row6_col3, #T_0ff15_row7_col0, #T_0ff15_row8_col10, #T_0ff15_row8_col17, #T_0ff15_row9_col17 {
#   background-color: rgba(244,244,244, .5);
#   color: black;
# }
# #T_0ff15_row1_col0, #T_0ff15_row1_col8, #T_0ff15_row1_col23, #T_0ff15_row2_col10, #T_0ff15_row3_col2, #T_0ff15_row4_col6, #T_0ff15_row4_col15, #T_0ff15_row5_col1, #T_0ff15_row5_col2, #T_0ff15_row6_col4, #T_0ff15_row7_col8, #T_0ff15_row8_col22, #T_0ff15_row9_col8, #T_0ff15_row10_col6 {
#   background-color: rgba(249,249,249, .5);
#   color: black;
# }
# #T_0ff15_row1_col3, #T_0ff15_row3_col6, #T_0ff15_row3_col13, #T_0ff15_row3_col27, #T_0ff15_row4_col13, #T_0ff15_row10_col12 {
#   background-color: rgba(234,234,234, .5);
#   color: black;
# }
# #T_0ff15_row1_col5 {
#   background-color: rgba(64,64,64, .5);
#   color: black;
# }
# #T_0ff15_row1_col9, #T_0ff15_row3_col20 {
#   background-color: rgba(232,232,232, .5);
#   color: black;
# }
# #T_0ff15_row1_col14, #T_0ff15_row1_col15 {
#   background-color: rgba(167,167,167, .5);
#   color: black;
# }
# #T_0ff15_row1_col17, #T_0ff15_row4_col0, #T_0ff15_row8_col0, #T_0ff15_row10_col10 {
#   background-color: rgba(213,213,213, .5);
#   color: black;
# }
# #T_0ff15_row1_col18, #T_0ff15_row6_col18 {
#   background-color: rgba(251,251,251, .5);
#   color: black;
# }
# #T_0ff15_row2_col12, #T_0ff15_row7_col14, #T_0ff15_row10_col15 {
#   background-color: rgba(203,203,203, .5);
#   color: black;
# }
# #T_0ff15_row2_col13, #T_0ff15_row10_col13 {
#   background-color: rgba(109,109,109, .5);
#   color: black;
# }
# #T_0ff15_row2_col16 {
#   background-color: rgba(156,156,156, .5);
#   color: black;
# }
# #T_0ff15_row2_col20, #T_0ff15_row4_col16 {
#   background-color: rgba(240,240,240, .5);
#   color: black;
# }
# #T_0ff15_row3_col0, #T_0ff15_row3_col23 {
#   background-color: rgba(253,214,175, .5);
#   color: black;
# }
# #T_0ff15_row3_col3, #T_0ff15_row3_col7, #T_0ff15_row3_col10, #T_0ff15_row3_col14, #T_0ff15_row10_col7, #T_0ff15_row10_col14, #T_0ff15_row10_col25 {
#   background-color: rgba(127,39,4, .5);
#   color: black;
# }
# #T_0ff15_row3_col5, #T_0ff15_row8_col4 {
#   background-color: rgba(115,115,115, .5);
#   color: black;
# }
# #T_0ff15_row3_col8, #T_0ff15_row10_col0 {
#   background-color: rgba(6,6,6, .5);
#   color: black;
# }
# #T_0ff15_row3_col9, #T_0ff15_row4_col11 {
#   background-color: rgba(228,228,228, .5);
#   color: black;
# }
# #T_0ff15_row3_col12 {
#   background-color: rgba(253,191,135, .5);
#   color: black;
# }
# #T_0ff15_row3_col16 {
#   background-color: rgba(253,218,183, .5);
#   color: black;
# }
# #T_0ff15_row3_col18 {
#   background-color: rgba(253,167,97, .5);
#   color: black;
# }
# #T_0ff15_row3_col19, #T_0ff15_row4_col7, #T_0ff15_row4_col21, #T_0ff15_row7_col4, #T_0ff15_row8_col8, #T_0ff15_row8_col11, #T_0ff15_row8_col19, #T_0ff15_row8_col25 {
#   background-color: rgba(238,238,238, .5);
#   color: black;
# }
# #T_0ff15_row3_col22 {
#   background-color: rgba(146,146,146, .5);
#   color: black;
# }
# #T_0ff15_row3_col24, #T_0ff15_row4_col19, #T_0ff15_row4_col25, #T_0ff15_row7_col6 {
#   background-color: rgba(218,218,218, .5);
#   color: black;
# }
# #T_0ff15_row4_col3 {
#   background-color: rgba(79,79,79, .5);
#   color: black;
# }
# #T_0ff15_row4_col4, #T_0ff15_row10_col4 {
#   background-color: rgba(39,39,39, .5);
#   color: black;
# }
# #T_0ff15_row4_col8, #T_0ff15_row4_col12, #T_0ff15_row5_col15, #T_0ff15_row9_col20 {
#   background-color: rgba(241,241,241, .5);
#   color: black;
# }
# #T_0ff15_row4_col9, #T_0ff15_row10_col16 {
#   background-color: rgba(210,210,210, .5);
#   color: black;
# }
# #T_0ff15_row4_col10 {
#   background-color: rgba(243,112,27, .5);
#   color: black;
# }
# #T_0ff15_row4_col14 {
#   background-color: rgba(253,203,154, .5);
#   color: black;
# }
# #T_0ff15_row4_col17 {
#   background-color: rgba(253,185,125, .5);
#   color: black;
# }
# #T_0ff15_row4_col18, #T_0ff15_row9_col7 {
#   background-color: rgba(236,236,236, .5);
#   color: black;
# }
# #T_0ff15_row4_col22, #T_0ff15_row6_col23, #T_0ff15_row7_col3, #T_0ff15_row8_col3, #T_0ff15_row10_col27 {
#   background-color: rgba(226,226,226, .5);
#   color: black;
# }
# #T_0ff15_row4_col23, #T_0ff15_row9_col23 {
#   background-color: rgba(220,220,220, .5);
#   color: black;
# }
# #T_0ff15

# %% [markdown]
# ```{note}
# The available features are column names of the survey data. They represent the different geopraphic or administrative boundaries in the selected report data.
#
# * `parent_boundary` is a geographic boundary such as a river basin or a category such as mountains
# * `feature_type` designates whether the location is at a river, lake or park
# * `feature_name` is the name of the river, lake or park
# ```
