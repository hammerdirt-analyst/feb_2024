# %%
# %load_ext watermark
import pandas as pd
import numpy as np
from typing import Type, Optional, Callable
from typing import List, Dict, Union, Tuple

from review_methods_tests import collect_vitals, find_missing, find_missing_loc_dates
from review_methods_tests import make_a_summary

import matplotlib.pyplot as plt
import matplotlib as mpl
import matplotlib.colors
from matplotlib.colors import LinearSegmentedColormap, ListedColormap

import setvariables as conf_
import reportclass as r_class

# %% [markdown]
# # Report class
#
# The report class is used to generate descriptive statistics and identify objects of interest for a query defined by geographic, adminsitrative and temporal bounds. The reference is the swiss federal report published in 2022.
#
# ## Defining and collecting the data
#
# The survey records are stored separately from the environmental and administrative data. Each survey is identified by an id that is a combination of the location and date of the survey `loc_date`. There can be up to 228 codes associated to one `loc_date`, most of them will be zero. The combination of `loc_date` and `code` should result in a unique value.
#
# ### basic requirements
#
# __Define the limits of the request:__
#    * temporal
#    * geographic (includes features and parent boundaries)
#    * object types
#    * level of aggregation
#
# Define what codes are being used
#
# The default setting is to combine all the fragmented plastics into one group (all sizes) and the same for fragmented expanded polystyrene and plastic bottle tops. This results in three codes that represent objects that are very similar. This topic has been addressed many times. These groups register not-trivial quantities at most surveys. However, the differentiation of these objects into their respective subgroups ie. plastic caps for drinnking v/s plastic caps for household cleaners is not considered a priority by all groups that have collected data in the past.
#
# * Gfrags
# * Gfoams
# * Gcaps
#
# __Define the reporting language:__
#
# The reporting language can be either French, German or English.
#
# __Note:__ The reporting language is only applied at the moment of display. The column names, feature labels and other underlying identifying criteria for the data remain unchanged. The column name definitions and translations are in the _random variables_ section.
#
# __Summary__
#
# From the Annex in `testing_data_models` we identified the column combinantions needed to slice the data depending on the report request. At the same time we identify the operations to be performed and when they are to be performed as different columns are used to group the data. This was summrised as follows:
#
#    * `df (pd.DataFrame)`: The input DataFrame containing data for analysis.
#    * `cumulative_columns (List, optional)`: List of columns to be considered for cumulative values.
#    * `boundary_labels (List, optional)`: List of labels for boundary summaries.
#    * `object_labels (List, optional)`: List of labels for individual objects.
#    * `object_columns (List, optional)`: List of columns identifying objects.
#    * `unit_agg (dict, optional)`: Aggregation methods for unit summaries.
#    * `unit_columns (List, optional)`: List of columns for unit summaries.
#    * `agg_groups (dict, optional)`: Aggregation methods for boundary summaries.
#
#
# ### Work data
#
# A report can be defined by providing the temporal and geographic bounds of interest. Below is the current method.
#
# __code sample:__
#
# ```python
# # starting data, can be MySQL or NoSQL calls
# # the three methods accept Callables, as long
# # as the out put is pd.DataFrame
# c_l = r_class.language_maps()
# surveys = r_class.collect_survey_data_for_report()
# codes, beaches, land_cover, land_use, streets, river_intersect_lakes = r_class.collect_env_data_for_report()
#
# survey_data = surveys.copy()
# survey_data = survey_data.merge(beaches['canton'], left_on='slug', right_index=True, validate='many_to_one')
#
# # temporal and geographic boundaries
# # user defined input
# boundaries = dict(canton='Valais', language='fr', start_date='2019-01-01', end_date='2022-01-01')
#
# # the level and label of the report
# # the language for display
# # the data for the report and all other
# # from the data range
# top_label, language, w_df, w_di = r_class.report_data(boundaries, survey_data.copy(), beaches, codes)
#
# # define the language map
# w_df.head().style.set_table_styles(conf_.table_css_styles)
# ```
#
# Which produces the following untranslated output.

# %%
# starting data, can be MySQL or NoSQL calls
# the three methods accept Callables, as long
# as the out put is pd.DataFrame
c_l = r_class.language_maps()
surveys = r_class.collect_survey_data_for_report()
codes, beaches, land_cover, land_use, streets, river_intersect_lakes = r_class.collect_env_data_for_report()

survey_data = surveys.copy()
survey_data = survey_data.merge(beaches['canton'], left_on='slug', right_index=True, validate='many_to_one')

# temporal and geographic boundaries
# user defined input
boundaries = dict(feature_name='lac-leman', language='fr', start_date="2020-03-01", end_date="2021-05-31")

# the level and label of the report
# the language for display
# the data for the report and all other
# from the data range
top_label, language, w_df, w_di = r_class.report_data(boundaries, survey_data.copy(), beaches, codes)

# define the language map
w_df.head().style.set_table_styles(conf_.table_css_styles)
# Out:
# <style type="text/css">
# #T_31dca tr:nth-child(even) {
#   background-color: rgba(139, 69, 19, 0.08);
# }
# #T_31dca tr:nth-child(odd) {
#   background: #FFF;
# }
# #T_31dca tr {
#   font-size: 10px;
# }
# #T_31dca th:nth-child(1) {
#   background-color: #FFF;
#   font-size: 12px;
#   text-align: left;
# }
# #T_31dca td {
#   padding: 4px;
#   font-size: 12px;
# }
# #T_31dca caption {
#   caption-side: bottom;
#   font-size: 1em;
#   text-align: left;
# }
# </style>
# <table id="T_31dca">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_31dca_level0_col0" class="col_heading level0 col0" >parent_boundary</th>
#       <th id="T_31dca_level0_col1" class="col_heading level0 col1" >code</th>
#       <th id="T_31dca_level0_col2" class="col_heading level0 col2" >length</th>
#       <th id="T_31dca_level0_col3" class="col_heading level0 col3" >slug</th>
#       <th id="T_31dca_level0_col4" class="col_heading level0 col4" >canton</th>
#       <th id="T_31dca_level0_col5" class="col_heading level0 col5" >groupname</th>
#       <th id="T_31dca_level0_col6" class="col_heading level0 col6" >feature_type</th>
#       <th id="T_31dca_level0_col7" class="col_heading level0 col7" >loc_date</th>
#       <th id="T_31dca_level0_col8" class="col_heading level0 col8" >feature_name</th>
#       <th id="T_31dca_level0_col9" class="col_heading level0 col9" >city</th>
#       <th id="T_31dca_level0_col10" class="col_heading level0 col10" >date</th>
#       <th id="T_31dca_level0_col11" class="col_heading level0 col11" >quantity</th>
#       <th id="T_31dca_level0_col12" class="col_heading level0 col12" >pcs_m</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_31dca_level0_row0" class="row_heading level0 row0" >59935</th>
#       <td id="T_31dca_row0_col0" class="data row0 col0" >rhone</td>
#       <td id="T_31dca_row0_col1" class="data row0 col1" >G1</td>
#       <td id="T_31dca_row0_col2" class="data row0 col2" >5</td>
#       <td id="T_31dca_row0_col3" class="data row0 col3" >vidy-ruines</td>
#       <td id="T_31dca_row0_col4" class="data row0 col4" >Vaud</td>
#       <td id="T_31dca_row0_col5" class="data row0 col5" >food and drink</td>
#       <td id="T_31dca_row0_col6" class="data row0 col6" >l</td>
#       <td id="T_31dca_row0_col7" class="data row0 col7" >('vidy-ruines', '2020-06-30')</td>
#       <td id="T_31dca_row0_col8" class="data row0 col8" >lac-leman</td>
#       <td id="T_31dca_row0_col9" class="data row0 col9" >Lausanne</td>
#       <td id="T_31dca_row0_col10" class="data row0 col10" >2020-06-30</td>
#       <td id="T_31dca_row0_col11" class="data row0 col11" >0</td>
#       <td id="T_31dca_row0_col12" class="data row0 col12" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_31dca_level0_row1" class="row_heading level0 row1" >59936</th>
#       <td id="T_31dca_row1_col0" class="data row1 col0" >rhone</td>
#       <td id="T_31dca_row1_col1" class="data row1 col1" >G1</td>
#       <td id="T_31dca_row1_col2" class="data row1 col2" >5</td>
#       <td id="T_31dca_row1_col3" class="data row1 col3" >vidy-ruines</td>
#       <td id="T_31dca_row1_col4" class="data row1 col4" >Vaud</td>
#       <td id="T_31dca_row1_col5" class="data row1 col5" >food and drink</td>
#       <td id="T_31dca_row1_col6" class="data row1 col6" >l</td>
#       <td id="T_31dca_row1_col7" class="data row1 col7" >('vidy-ruines', '2020-08-01')</td>
#       <td id="T_31dca_row1_col8" class="data row1 col8" >lac-leman</td>
#       <td id="T_31dca_row1_col9" class="data row1 col9" >Lausanne</td>
#       <td id="T_31dca_row1_col10" class="data row1 col10" >2020-08-01</td>
#       <td id="T_31dca_row1_col11" class="data row1 col11" >0</td>
#       <td id="T_31dca_row1_col12" class="data row1 col12" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_31dca_level0_row2" class="row_heading level0 row2" >59937</th>
#       <td id="T_31dca_row2_col0" class="data row2 col0" >rhone</td>
#       <td id="T_31dca_row2_col1" class="data row2 col1" >G1</td>
#       <td id="T_31dca_row2_col2" class="data row2 col2" >5</td>
#       <td id="T_31dca_row2_col3" class="data row2 col3" >vidy-ruines</td>
#       <td id="T_31dca_row2_col4" class="data row2 col4" >Vaud</td>
#       <td id="T_31dca_row2_col5" class="data row2 col5" >food and drink</td>
#       <td id="T_31dca_row2_col6" class="data row2 col6" >l</td>
#       <td id="T_31dca_row2_col7" class="data row2 col7" >('vidy-ruines', '2020-09-02')</td>
#       <td id="T_31dca_row2_col8" class="data row2 col8" >lac-leman</td>
#       <td id="T_31dca_row2_col9" class="data row2 col9" >Lausanne</td>
#       <td id="T_31dca_row2_col10" class="data row2 col10" >2020-09-02</td>
#       <td id="T_31dca_row2_col11" class="data row2 col11" >0</td>
#       <td id="T_31dca_row2_col12" class="data row2 col12" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_31dca_level0_row3" class="row_heading level0 row3" >59938</th>
#       <td id="T_31dca_row3_col0" class="data row3 col0" >rhone</td>
#       <td id="T_31dca_row3_col1" class="data row3 col1" >G1</td>
#       <td id="T_31dca_row3_col2" class="data row3 col2" >5</td>
#       <td id="T_31dca_row3_col3" class="data row3 col3" >vidy-ruines</td>
#       <td id="T_31dca_row3_col4" class="data row3 col4" >Vaud</td>
#       <td id="T_31dca_row3_col5" class="data row3 col5" >food and drink</td>
#       <td id="T_31dca_row3_col6" class="data row3 col6" >l</td>
#       <td id="T_31dca_row3_col7" class="data row3 col7" >('vidy-ruines', '2020-12-01')</td>
#       <td id="T_31dca_row3_col8" class="data row3 col8" >lac-leman</td>
#       <td id="T_31dca_row3_col9" class="data row3 col9" >Lausanne</td>
#       <td id="T_31dca_row3_col10" class="data row3 col10" >2020-12-01</td>
#       <td id="T_31dca_row3_col11" class="data row3 col11" >0</td>
#       <td id="T_31dca_row3_col12" class="data row3 col12" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_31dca_level0_row4" class="row_heading level0 row4" >59939</th>
#       <td id="T_31dca_row4_col0" class="data row4 col0" >rhone</td>
#       <td id="T_31dca_row4_col1" class="data row4 col1" >G1</td>
#       <td id="T_31dca_row4_col2" class="data row4 col2" >8</td>
#       <td id="T_31dca_row4_col3" class="data row4 col3" >vidy-ruines</td>
#       <td id="T_31dca_row4_col4" class="data row4 col4" >Vaud</td>
#       <td id="T_31dca_row4_col5" class="data row4 col5" >food and drink</td>
#       <td id="T_31dca_row4_col6" class="data row4 col6" >l</td>
#       <td id="T_31dca_row4_col7" class="data row4 col7" >('vidy-ruines', '2021-03-04')</td>
#       <td id="T_31dca_row4_col8" class="data row4 col8" >lac-leman</td>
#       <td id="T_31dca_row4_col9" class="data row4 col9" >Lausanne</td>
#       <td id="T_31dca_row4_col10" class="data row4 col10" >2021-03-04</td>
#       <td id="T_31dca_row4_col11" class="data row4 col11" >0</td>
#       <td id="T_31dca_row4_col12" class="data row4 col12" >0.000000</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Reporting categories
#
# The first variable of the input is used to define the hierarchy of the report. For administrative purposes a vertical approach that reflects areas of responsibility is important. For estimating values the geographic/topographic attributes are more important.
#
# The survey data is labeled for these purposes. The columns `parent_boundary`, `feature_type` and `feature_name` are the topographic features.
#
# 1. `parent_boundary`: the name of the: river basin, catchment area, park, name of geograhphic region or other zone defined by swiss geo admin.
# 2. `feature_type`: lake, river or park
# 3. `feature_name`: the name of the lake, river or park
#
# The `geo_h` array sets the order for reporting. Reports for cantons can contain subreports for all the values in the array, by default the cantonal results will reference the IQAASL report for threshold or prior results. Reports for cities will contain only geographic categories with reference to cantonal results.
#
# __code sample:__
#
#
# ```python
#
#
# geo_h = ['parent_boundary', 'feature_type',  'feature_name','canton', 'city']
#
#
# def categorize_work_data(df, labels, columns_of_interest: List[str] = geo_h, sample_id: str = 'loc_date'):
#
#     data = df[df[labels[0]] == labels[1]].copy()
#
#     summaries = columns_of_interest
#     print(summaries)
#
#     # if city is selected the available boundaries
#     # are geographic. A city is in only one canton
#     # if canton is selected then city becomes a category
#     # for which a report can be produced
#     if labels[0] == columns_of_interest[-1]:
#         summaries = columns_of_interest[:-2]
#     if labels[0] == columns_of_interest[-2]:
#         summaries = [*columns_of_interest[:-2], columns_of_interest[-1]]
#
#     new_columns = list(set([sample_id, *summaries]))
#     d = data[new_columns].copy()
#     res = {}
#     for an_attribute in new_columns:
#         datt = d[an_attribute].unique()
#         res.update({an_attribute: datt})
#
#     res['samples'] = res.pop('loc_date')
#
#     return {labels[1]:res}
#
# # this categorizes the survey data into search terms
# # the available data or reporting categories are retrieved
# # by getting the length of the array for each category
# # if the category is not present then the data is not available
# parent_categories = categorize_work_data(w_df, top_label)
# p_vals = parent_categories[boundaries[top_label[0]]]
#
# # the type and number of reports available
# reporting_categories = {k:len(v) for k, v in p_vals.items()}
# reporting_categories
# ```
#
# Which gives the following result:

# %%
# this categorizes the survey data into search terms
# the available data or reporting categories are retrieved
# by getting the length of the array for each category
# if the category is not present then the data is not available
parent_categories = r_class.categorize_work_data(w_df, top_label)
p_vals = parent_categories[boundaries[top_label[0]]]

# the type and number of reports available
reporting_categories = {k:len(v) for k, v in p_vals.items()}
reporting_categories
# Out:
# {'parent_boundary': 1,
#  'canton': 3,
#  'feature_type': 1,
#  'feature_name': 1,
#  'city': 13,
#  'samples': 98}

# %% [markdown]
# The same operation can be performed at each level. The first call to `categorize_work_data` gives the structure of the report. For each key value of the reporting categories there wil be a set of descriptive statistics.
#
# For example, a detailed report on all feature types within the canton includes the following summary data for each feature type.
#
# __code sample:__
#
# ```python
# # identify and count the results from parcs
# parc_features = categorize_work_data(w_df[w_df.feature_type == p_vals['feature_type'][0]], top_label)
#
# # count the contents in each attribute
# {k:len(v) for k, v in parc_features[top_label[1]].items()}
#
# # out =>
#
# {'city': 6,
#  'feature_type': 1,
#  'parent_boundary': 1,
#  'feature_name': 1,
#  'samples': 7}
#
# ```
#
# In this example there are 7 samples from 6 cities in the parcs feature_type.

# %% [markdown]
# The summary of each label for each feature in the current data set can be obtained by providing the feature of interest to the groupby columns. By default the sample id: `loc_date` and the location name `slug` are required.
#
# __Essential:__ The boundaries variable defines the top level data structure, for example: `boundaries={'canton': 'Valais', 'language': 'fr', 'start_date': '2019-01-01', 'end_date': '2022-01-01'}` will produce a dataframe with records only from the canton of Valais within the dates defined. Tables and charts will be translated to french.
#
# The report class uses the resulting data structure to define reports for the different features within the dataframe.
#
# ## The report class
#
# The report class provides the set of arguments that define the structure of the report based on the user input. Those arguments are a property of the class `ReportClass.feautures`. The `ReportClass` also identifies objects that meet the criteria defined by `mc_criteria_one` and `mc_criteria_two`.
#
# To start a `ReportClass` call it with the dataframes of interest, the boundaries, the top level report, the language and the language map.
#
# ```python
# a_report = r_class.ReportClass(w_df, w_di, boundaries, top_label, 'fr', c_l)
# a_report.the_number_of_attributes_in_a_feature('feature_type')
# ```
#
# ### The number and types of features in a report
#
# Once a `ReportClass` is initiated a summary of the attributes can be obtained:

# %%
top_label, language, w_df, w_di = r_class.report_data(boundaries, survey_data.copy(), beaches, codes)          
a_report = r_class.ReportClass(w_df,boundaries, top_label, 'fr', c_l)
r_class.translated_and_style_for_display(a_report.the_number_of_attributes_in_a_feature('feature_type'), a_report.lang_maps[a_report.language], a_report.language, gradient=False)
# a_report.features
# Out:
# <style type="text/css">
# #T_1abcf tr:nth-child(even) {
#   background-color: rgba(139, 69, 19, 0.08);
# }
# #T_1abcf tr:nth-child(odd) {
#   background: #FFF;
# }
# #T_1abcf tr {
#   font-size: 10px;
# }
# #T_1abcf th:nth-child(1) {
#   background-color: #FFF;
#   font-size: 12px;
#   text-align: left;
# }
# #T_1abcf td {
#   padding: 4px;
#   font-size: 12px;
# }
# #T_1abcf caption {
#   caption-side: bottom;
#   font-size: 1em;
#   text-align: left;
# }
# </style>
# <table id="T_1abcf">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_1abcf_level0_col0" class="col_heading level0 col0" >Région</th>
#       <th id="T_1abcf_level0_col1" class="col_heading level0 col1" >Canton</th>
#       <th id="T_1abcf_level0_col2" class="col_heading level0 col2" >Zone</th>
#       <th id="T_1abcf_level0_col3" class="col_heading level0 col3" >Feature_Name</th>
#       <th id="T_1abcf_level0_col4" class="col_heading level0 col4" >Ville</th>
#       <th id="T_1abcf_level0_col5" class="col_heading level0 col5" >Échantillons</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1abcf_level0_row0" class="row_heading level0 row0" >Lac</th>
#       <td id="T_1abcf_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_1abcf_row0_col1" class="data row0 col1" >3</td>
#       <td id="T_1abcf_row0_col2" class="data row0 col2" >1</td>
#       <td id="T_1abcf_row0_col3" class="data row0 col3" >1</td>
#       <td id="T_1abcf_row0_col4" class="data row0 col4" >13</td>
#       <td id="T_1abcf_row0_col5" class="data row0 col5" >98</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# #### A top level description
#
# The first out put says there are three feature types (lakes, rivers and parks) in the data. There is one lake that was sampled 11 times, a river was sampled 4 times and the parks were sampled 7 times. In total there were 11 cities, 4 on the river, 6 in the parcs feature and 1 on the lake.
#
# Recall that the geographic column names are: `['feature_type', 'feature_name', 'parent_name']`.  The suvey results from each sector can be compared by selecting the column name of interest. Depending on the value of `boundaries` all the column names may not be available. There is a method to identify exactly what features are available. Note in the example below, canton is not an option. This is because the boundaries were set for a canton.
#
# ```python
# my_feautures = my_report_class.available_features()
#
# print(my_features)
#
# => ['parent_boundary', 'feature_type', 'feature_name', 'city']
# ```
#
# The `summarize_feature_labels` method in the `ReportClass` creates a summary of the sample totals for each label of the selected feature. Calling the `translated_and_style_for_display` method puts the table to html and applies language specific formatting using the `dataframe.style` method. The index and column names are translated using the language maps.
#
# ```python
# feature_type_summary =  my_report_class.summarize_feature_labels('feature_type')
#
# translated_and_style_for_display(feature_type_summary, my_report.language_maps, my_report.language, gradient=False)
# ```
#
# Combined with the output from above a desctription of the data and how it was collected can be constructed, the higlighted text can be called from the active variables.
# > There were `13'782` objects identified in the period between `2019-01-01` and `2021-12-31` in the `canton` of `Valais`. In total, `22` samples were recorded, `11` on the `lake-shore`, `7` in `ski-areas` and `4` on `riverbanks`.  The lake samples were recorded from `one` `city` on the other hand the alpes and rivers were taken from `10` `different cities`. The `median` sample total of _pieces of trash per meter_ `pcs/m` is highest at the `lakeside`, followed by the `parcs` and `rivers`.
#
# ```{admonition} Ships search terms
# The `ReportClass.features` is a dictionary or .JSON file that contains the common labled geographic name of the region in question. Structuring these into search terms is a way to integrate a LLM into the analysis.
# ```

# %%
r_class.translated_and_style_for_display(a_report.summarize_feature_labels('feature_type'), a_report.lang_maps[a_report.language], a_report.language, gradient=False)
# Out:
# <style type="text/css">
# #T_cb6e1 tr:nth-child(even) {
#   background-color: rgba(139, 69, 19, 0.08);
# }
# #T_cb6e1 tr:nth-child(odd) {
#   background: #FFF;
# }
# #T_cb6e1 tr {
#   font-size: 10px;
# }
# #T_cb6e1 th:nth-child(1) {
#   background-color: #FFF;
#   font-size: 12px;
#   text-align: left;
# }
# #T_cb6e1 td {
#   padding: 4px;
#   font-size: 12px;
# }
# #T_cb6e1 caption {
#   caption-side: bottom;
#   font-size: 1em;
#   text-align: left;
# }
# </style>
# <table id="T_cb6e1">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_cb6e1_level0_col0" class="col_heading level0 col0" >Pcs_M</th>
#     </tr>
#     <tr>
#       <th class="index_name level1" >label</th>
#       <th id="T_cb6e1_level1_col0" class="col_heading level1 col0" >L</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_cb6e1_level0_row0" class="row_heading level0 row0" >25%</th>
#       <td id="T_cb6e1_row0_col0" class="data row0 col0" >2,30</td>
#     </tr>
#     <tr>
#       <th id="T_cb6e1_level0_row1" class="row_heading level0 row1" >50%</th>
#       <td id="T_cb6e1_row1_col0" class="data row1 col0" >4,50</td>
#     </tr>
#     <tr>
#       <th id="T_cb6e1_level0_row2" class="row_heading level0 row2" >75%</th>
#       <td id="T_cb6e1_row2_col0" class="data row2 col0" >9,68</td>
#     </tr>
#     <tr>
#       <th id="T_cb6e1_level0_row3" class="row_heading level0 row3" >Échantillons</th>
#       <td id="T_cb6e1_row3_col0" class="data row3 col0" >98</td>
#     </tr>
#     <tr>
#       <th id="T_cb6e1_level0_row4" class="row_heading level0 row4" >Max</th>
#       <td id="T_cb6e1_row4_col0" class="data row4 col0" >66,17</td>
#     </tr>
#     <tr>
#       <th id="T_cb6e1_level0_row5" class="row_heading level0 row5" >Moyenne</th>
#       <td id="T_cb6e1_row5_col0" class="data row5 col0" >8,66</td>
#     </tr>
#     <tr>
#       <th id="T_cb6e1_level0_row6" class="row_heading level0 row6" >Min</th>
#       <td id="T_cb6e1_row6_col0" class="data row6 col0" >0,22</td>
#     </tr>
#     <tr>
#       <th id="T_cb6e1_level0_row7" class="row_heading level0 row7" >Écart-Type</th>
#       <td id="T_cb6e1_row7_col0" class="data row7 col0" >11,67</td>
#     </tr>
#     <tr>
#       <th id="T_cb6e1_level0_row8" class="row_heading level0 row8" >Total</th>
#       <td id="T_cb6e1_row8_col0" class="data row8 col0" >27'447</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# #### By criteria
#
# Objects can be selected by criteria. The default criteria requires that the quantity be in the top ten or the fail rate >= .5. This can be changed at any time using the keywords when the class is called or setting the class variables in the form `my_report_class.criteria_one = anewvalue`.
#
# ```python
# objects_selected_by_criteria = my_report_class.most_common
# translated_and_style_for_display(a_report.most_common, a_report.lang_maps[a_report.language], a_report.language, gradient=False)
# ```
#
# Calling `my_report_class.most_common` will return a dataframe that has the test statistic and description of all objects that meet the criteria.

# %%
r_class.translated_and_style_for_display(a_report.most_common, a_report.lang_maps[a_report.language], a_report.language, gradient=False)
# Out:
# <style type="text/css">
# #T_3bfd7 tr:nth-child(even) {
#   background-color: rgba(139, 69, 19, 0.08);
# }
# #T_3bfd7 tr:nth-child(odd) {
#   background: #FFF;
# }
# #T_3bfd7 tr {
#   font-size: 10px;
# }
# #T_3bfd7 th:nth-child(1) {
#   background-color: #FFF;
#   font-size: 12px;
#   text-align: left;
# }
# #T_3bfd7 td {
#   padding: 4px;
#   font-size: 12px;
# }
# #T_3bfd7 caption {
#   caption-side: bottom;
#   font-size: 1em;
#   text-align: left;
# }
# </style>
# <table id="T_3bfd7">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_3bfd7_level0_col0" class="col_heading level0 col0" >Quantité</th>
#       <th id="T_3bfd7_level0_col1" class="col_heading level0 col1" >% Du Total</th>
#       <th id="T_3bfd7_level0_col2" class="col_heading level0 col2" >Pcs/M</th>
#       <th id="T_3bfd7_level0_col3" class="col_heading level0 col3" >Taux D'Échec</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3bfd7_level0_row0" class="row_heading level0 row0" >Fragments De Plastique: G80, G79, G78, G75</th>
#       <td id="T_3bfd7_row0_col0" class="data row0 col0" >4'212</td>
#       <td id="T_3bfd7_row0_col1" class="data row0 col1" >0,15</td>
#       <td id="T_3bfd7_row0_col2" class="data row0 col2" >0,10</td>
#       <td id="T_3bfd7_row0_col3" class="data row0 col3" >0,97</td>
#     </tr>
#     <tr>
#       <th id="T_3bfd7_level0_row1" class="row_heading level0 row1" >Fragments De Polystyrène Expansé: G76, G81, G82, G83</th>
#       <td id="T_3bfd7_row1_col0" class="data row1 col0" >3'586</td>
#       <td id="T_3bfd7_row1_col1" class="data row1 col1" >0,13</td>
#       <td id="T_3bfd7_row1_col2" class="data row1 col2" >0,04</td>
#       <td id="T_3bfd7_row1_col3" class="data row1 col3" >0,84</td>
#     </tr>
#     <tr>
#       <th id="T_3bfd7_level0_row2" class="row_heading level0 row2" >Mégots Et Filtres À Cigarettes</th>
#       <td id="T_3bfd7_row2_col0" class="data row2 col0" >3'116</td>
#       <td id="T_3bfd7_row2_col1" class="data row2 col1" >0,11</td>
#       <td id="T_3bfd7_row2_col2" class="data row2 col2" >0,47</td>
#       <td id="T_3bfd7_row2_col3" class="data row2 col3" >0,95</td>
#     </tr>
#     <tr>
#       <th id="T_3bfd7_level0_row3" class="row_heading level0 row3" >Emballages De Bonbons, De Snacks</th>
#       <td id="T_3bfd7_row3_col0" class="data row3 col0" >1'679</td>
#       <td id="T_3bfd7_row3_col1" class="data row3 col1" >0,06</td>
#       <td id="T_3bfd7_row3_col2" class="data row3 col2" >0,21</td>
#       <td id="T_3bfd7_row3_col3" class="data row3 col3" >0,96</td>
#     </tr>
#     <tr>
#       <th id="T_3bfd7_level0_row4" class="row_heading level0 row4" >Pellets Industriels (Gpi)</th>
#       <td id="T_3bfd7_row4_col0" class="data row4 col0" >1'387</td>
#       <td id="T_3bfd7_row4_col1" class="data row4 col1" >0,05</td>
#       <td id="T_3bfd7_row4_col2" class="data row4 col2" >0,00</td>
#       <td id="T_3bfd7_row4_col3" class="data row4 col3" >0,47</td>
#     </tr>
#     <tr>
#       <th id="T_3bfd7_level0_row5" class="row_heading level0 row5" >Couvercles En Plastique Bouteille:  G21, G22, G23, G24</th>
#       <td id="T_3bfd7_row5_col0" class="data row5 col0" >1'212</td>
#       <td id="T_3bfd7_row5_col1" class="data row5 col1" >0,04</td>
#       <td id="T_3bfd7_row5_col2" class="data row5 col2" >0,02</td>
#       <td id="T_3bfd7_row5_col3" class="data row5 col3" >0,89</td>
#     </tr>
#     <tr>
#       <th id="T_3bfd7_level0_row6" class="row_heading level0 row6" >Coton-Tige</th>
#       <td id="T_3bfd7_row6_col0" class="data row6 col0" >1'112</td>
#       <td id="T_3bfd7_row6_col1" class="data row6 col1" >0,04</td>
#       <td id="T_3bfd7_row6_col2" class="data row6 col2" >0,12</td>
#       <td id="T_3bfd7_row6_col3" class="data row6 col3" >0,82</td>
#     </tr>
#     <tr>
#       <th id="T_3bfd7_level0_row7" class="row_heading level0 row7" >Mousse De Plastique Pour L'Isolation Thermique</th>
#       <td id="T_3bfd7_row7_col0" class="data row7 col0" >1'097</td>
#       <td id="T_3bfd7_row7_col1" class="data row7 col1" >0,04</td>
#       <td id="T_3bfd7_row7_col2" class="data row7 col2" >0,04</td>
#       <td id="T_3bfd7_row7_col3" class="data row7 col3" >0,78</td>
#     </tr>
#     <tr>
#       <th id="T_3bfd7_level0_row8" class="row_heading level0 row8" >Bâche, Feuille Plastique Industrielle</th>
#       <td id="T_3bfd7_row8_col0" class="data row8 col0" >1'058</td>
#       <td id="T_3bfd7_row8_col1" class="data row8 col1" >0,04</td>
#       <td id="T_3bfd7_row8_col2" class="data row8 col2" >0,09</td>
#       <td id="T_3bfd7_row8_col3" class="data row8 col3" >0,78</td>
#     </tr>
#     <tr>
#       <th id="T_3bfd7_level0_row9" class="row_heading level0 row9" >Polystyrène < 5Mm</th>
#       <td id="T_3bfd7_row9_col0" class="data row9 col0" >689</td>
#       <td id="T_3bfd7_row9_col1" class="data row9 col1" >0,03</td>
#       <td id="T_3bfd7_row9_col2" class="data row9 col2" >0,00</td>
#       <td id="T_3bfd7_row9_col3" class="data row9 col3" >0,30</td>
#     </tr>
#     <tr>
#       <th id="T_3bfd7_level0_row10" class="row_heading level0 row10" >Déchets De Construction En Plastique</th>
#       <td id="T_3bfd7_row10_col0" class="data row10 col0" >584</td>
#       <td id="T_3bfd7_row10_col1" class="data row10 col1" >0,02</td>
#       <td id="T_3bfd7_row10_col2" class="data row10 col2" >0,06</td>
#       <td id="T_3bfd7_row10_col3" class="data row10 col3" >0,66</td>
#     </tr>
#     <tr>
#       <th id="T_3bfd7_level0_row11" class="row_heading level0 row11" >Verre Brisé</th>
#       <td id="T_3bfd7_row11_col0" class="data row11 col0" >510</td>
#       <td id="T_3bfd7_row11_col1" class="data row11 col1" >0,02</td>
#       <td id="T_3bfd7_row11_col2" class="data row11 col2" >0,03</td>
#       <td id="T_3bfd7_row11_col3" class="data row11 col3" >0,58</td>
#     </tr>
#     <tr>
#       <th id="T_3bfd7_level0_row12" class="row_heading level0 row12" >Cartouches De Fusil De Chasse</th>
#       <td id="T_3bfd7_row12_col0" class="data row12 col0" >345</td>
#       <td id="T_3bfd7_row12_col1" class="data row12 col1" >0,01</td>
#       <td id="T_3bfd7_row12_col2" class="data row12 col2" >0,01</td>
#       <td id="T_3bfd7_row12_col3" class="data row12 col3" >0,52</td>
#     </tr>
#     <tr>
#       <th id="T_3bfd7_level0_row13" class="row_heading level0 row13" >Bouchons De Bouteilles En Métal, Couvercles Et Tirettes</th>
#       <td id="T_3bfd7_row13_col0" class="data row13 col0" >308</td>
#       <td id="T_3bfd7_row13_col1" class="data row13 col1" >0,01</td>
#       <td id="T_3bfd7_row13_col2" class="data row13 col2" >0,03</td>
#       <td id="T_3bfd7_row13_col3" class="data row13 col3" >0,71</td>
#     </tr>
#     <tr>
#       <th id="T_3bfd7_level0_row14" class="row_heading level0 row14" >Tabac Emballages En Plastique</th>
#       <td id="T_3bfd7_row14_col0" class="data row14 col0" >295</td>
#       <td id="T_3bfd7_row14_col1" class="data row14 col1" >0,01</td>
#       <td id="T_3bfd7_row14_col2" class="data row14 col2" >0,02</td>
#       <td id="T_3bfd7_row14_col3" class="data row14 col3" >0,55</td>
#     </tr>
#     <tr>
#       <th id="T_3bfd7_level0_row15" class="row_heading level0 row15" >Emballage Fast Food</th>
#       <td id="T_3bfd7_row15_col0" class="data row15 col0" >288</td>
#       <td id="T_3bfd7_row15_col1" class="data row15 col1" >0,01</td>
#       <td id="T_3bfd7_row15_col2" class="data row15 col2" >0,01</td>
#       <td id="T_3bfd7_row15_col3" class="data row15 col3" >0,51</td>
#     </tr>
#     <tr>
#       <th id="T_3bfd7_level0_row16" class="row_heading level0 row16" >Pailles Et Agitateurs</th>
#       <td id="T_3bfd7_row16_col0" class="data row16 col0" >278</td>
#       <td id="T_3bfd7_row16_col1" class="data row16 col1" >0,01</td>
#       <td id="T_3bfd7_row16_col2" class="data row16 col2" >0,04</td>
#       <td id="T_3bfd7_row16_col3" class="data row16 col3" >0,73</td>
#     </tr>
#     <tr>
#       <th id="T_3bfd7_level0_row17" class="row_heading level0 row17" >Bâtonnets De Sucette</th>
#       <td id="T_3bfd7_row17_col0" class="data row17 col0" >237</td>
#       <td id="T_3bfd7_row17_col1" class="data row17 col1" >0,01</td>
#       <td id="T_3bfd7_row17_col2" class="data row17 col2" >0,03</td>
#       <td id="T_3bfd7_row17_col3" class="data row17 col3" >0,66</t

# %% [markdown]
# #### Results by criteria and feature type
#
# Once the the objects of intereste are identified (criteria) they can be compared accross the diferent feature_types and labels.
#
# ```python
# t = a_cumulative_report(w_df[w_df.code.isin(a_report.most_common.index)], feature_name='feature_type', object_column='code')
# translated_and_style_for_display(t, a_report.lang_maps[a_report.language], a_report.language, gradient=True)
# ```
# For example the most common objects are found at different densitiies depending on the feature type.

# %%
t= r_class.a_cumulative_report(w_df[w_df.code.isin(a_report.most_common.index)], feature_name='feature_type', object_column='code')
r_class.translated_and_style_for_display(t, a_report.lang_maps[a_report.language], a_report.language, gradient=True)
# Out:
# <style type="text/css">
# #T_39595 tr:nth-child(even) {
#   background-color: rgba(139, 69, 19, 0.08);
# }
# #T_39595 tr:nth-child(odd) {
#   background: #FFF;
# }
# #T_39595 tr {
#   font-size: 10px;
# }
# #T_39595 th:nth-child(1) {
#   background-color: #FFF;
#   font-size: 12px;
#   text-align: left;
# }
# #T_39595 td {
#   padding: 4px;
#   font-size: 12px;
# }
# #T_39595 caption {
#   caption-side: bottom;
#   font-size: 1em;
#   text-align: left;
# }
# #T_39595_row0_col0, #T_39595_row0_col1, #T_39595_row15_col0, #T_39595_row15_col1 {
#   background-color: rgba(252,252,252, .5);
#   color: black;
# }
# #T_39595_row1_col0, #T_39595_row1_col1, #T_39595_row4_col0, #T_39595_row4_col1, #T_39595_row7_col0, #T_39595_row7_col1, #T_39595_row12_col0, #T_39595_row12_col1 {
#   background-color: rgba(249,249,249, .5);
#   color: black;
# }
# #T_39595_row2_col0, #T_39595_row2_col1, #T_39595_row3_col0, #T_39595_row3_col1 {
#   background-color: rgba(255,255,255, .5);
#   color: black;
# }
# #T_39595_row5_col0, #T_39595_row5_col1, #T_39595_row6_col0, #T_39595_row6_col1, #T_39595_row10_col0, #T_39595_row10_col1 {
#   background-color: rgba(247,247,247, .5);
#   color: black;
# }
# #T_39595_row8_col0, #T_39595_row8_col1 {
#   background-color: rgba(254,239,224, .5);
#   color: black;
# }
# #T_39595_row9_col0, #T_39595_row9_col1 {
#   background-color: rgba(156,156,156, .5);
#   color: black;
# }
# #T_39595_row11_col0, #T_39595_row11_col1 {
#   background-color: rgba(248,248,248, .5);
#   color: black;
# }
# #T_39595_row13_col0, #T_39595_row13_col1 {
#   background-color: rgba(244,244,244, .5);
#   color: black;
# }
# #T_39595_row14_col0, #T_39595_row14_col1 {
#   background-color: rgba(226,226,226, .5);
#   color: black;
# }
# #T_39595_row16_col0, #T_39595_row16_col1 {
#   background-color: rgba(222,222,222, .5);
#   color: black;
# }
# #T_39595_row17_col0, #T_39595_row17_col1 {
#   background-color: rgba(240,240,240, .5);
#   color: black;
# }
# #T_39595_row18_col0, #T_39595_row18_col1 {
#   background-color: rgba(213,213,213, .5);
#   color: black;
# }
# #T_39595_row19_col0, #T_39595_row19_col1 {
#   background-color: rgba(218,218,218, .5);
#   color: black;
# }
# #T_39595_row20_col0, #T_39595_row20_col1 {
#   background-color: rgba(128,128,128, .5);
#   color: black;
# }
# #T_39595_row21_col0, #T_39595_row21_col1 {
#   background-color: rgba(253,176,110, .5);
#   color: black;
# }
# </style>
# <table id="T_39595">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_39595_level0_col0" class="col_heading level0 col0" >Lac</th>
#       <th id="T_39595_level0_col1" class="col_heading level0 col1" >Cumulé</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_39595_level0_row0" class="row_heading level0 row0" >Emballage Fast Food</th>
#       <td id="T_39595_row0_col0" class="data row0 col0" >0,01</td>
#       <td id="T_39595_row0_col1" class="data row0 col1" >0,01</td>
#     </tr>
#     <tr>
#       <th id="T_39595_level0_row1" class="row_heading level0 row1" >Médical Conteneurs/Tubes/ Emballages</th>
#       <td id="T_39595_row1_col0" class="data row1 col0" >0,02</td>
#       <td id="T_39595_row1_col1" class="data row1 col1" >0,02</td>
#     </tr>
#     <tr>
#       <th id="T_39595_level0_row2" class="row_heading level0 row2" >Pellets Industriels (Gpi)</th>
#       <td id="T_39595_row2_col0" class="data row2 col0" >0,00</td>
#       <td id="T_39595_row2_col1" class="data row2 col1" >0,00</td>
#     </tr>
#     <tr>
#       <th id="T_39595_level0_row3" class="row_heading level0 row3" >Polystyrène < 5Mm</th>
#       <td id="T_39595_row3_col0" class="data row3 col0" >0,00</td>
#       <td id="T_39595_row3_col1" class="data row3 col1" >0,00</td>
#     </tr>
#     <tr>
#       <th id="T_39595_level0_row4" class="row_heading level0 row4" >Papier D'Emballage D'Aluminium</th>
#       <td id="T_39595_row4_col0" class="data row4 col0" >0,02</td>
#       <td id="T_39595_row4_col1" class="data row4 col1" >0,02</td>
#     </tr>
#     <tr>
#       <th id="T_39595_level0_row5" class="row_heading level0 row5" >Bouchons De Bouteilles En Métal, Couvercles Et Tirettes</th>
#       <td id="T_39595_row5_col0" class="data row5 col0" >0,03</td>
#       <td id="T_39595_row5_col1" class="data row5 col1" >0,03</td>
#     </tr>
#     <tr>
#       <th id="T_39595_level0_row6" class="row_heading level0 row6" >Verre Brisé</th>
#       <td id="T_39595_row6_col0" class="data row6 col0" >0,03</td>
#       <td id="T_39595_row6_col1" class="data row6 col1" >0,03</td>
#     </tr>
#     <tr>
#       <th id="T_39595_level0_row7" class="row_heading level0 row7" >Tabac Emballages En Plastique</th>
#       <td id="T_39595_row7_col0" class="data row7 col0" >0,02</td>
#       <td id="T_39595_row7_col1" class="data row7 col1" >0,02</td>
#     </tr>
#     <tr>
#       <th id="T_39595_level0_row8" class="row_heading level0 row8" >Mégots Et Filtres À Cigarettes</th>
#       <td id="T_39595_row8_col0" class="data row8 col0" >0,47</td>
#       <td id="T_39595_row8_col1" class="data row8 col1" >0,47</td>
#     </tr>
#     <tr>
#       <th id="T_39595_level0_row9" class="row_heading level0 row9" >Emballages De Bonbons, De Snacks</th>
#       <td id="T_39595_row9_col0" class="data row9 col0" >0,21</td>
#       <td id="T_39595_row9_col1" class="data row9 col1" >0,21</td>
#     </tr>
#     <tr>
#       <th id="T_39595_level0_row10" class="row_heading level0 row10" >Bâtonnets De Sucette</th>
#       <td id="T_39595_row10_col0" class="data row10 col0" >0,03</td>
#       <td id="T_39595_row10_col1" class="data row10 col1" >0,03</td>
#     </tr>
#     <tr>
#       <th id="T_39595_level0_row11" class="row_heading level0 row11" >Jouets Et Faveurs De Fête</th>
#       <td id="T_39595_row11_col0" class="data row11 col0" >0,03</td>
#       <td id="T_39595_row11_col1" class="data row11 col1" >0,03</td>
#     </tr>
#     <tr>
#       <th id="T_39595_level0_row12" class="row_heading level0 row12" >Gobelets, Couvercles, Mousse À Usage Unique Et Plastique Dur</th>
#       <td id="T_39595_row12_col0" class="data row12 col0" >0,02</td>
#       <td id="T_39595_row12_col1" class="data row12 col1" >0,02</td>
#     </tr>
#     <tr>
#       <th id="T_39595_level0_row13" class="row_heading level0 row13" >Pailles Et Agitateurs</th>
#       <td id="T_39595_row13_col0" class="data row13 col0" >0,04</td>
#       <td id="T_39595_row13_col1" class="data row13 col1" >0,04</td>
#     </tr>
#     <tr>
#       <th id="T_39595_level0_row14" class="row_heading level0 row14" >Bâche, Feuille Plastique Industrielle</th>
#       <td id="T_39595_row14_col0" class="data row14 col0" >0,09</td>
#       <td id="T_39595_row14_col1" class="data row14 col1" >0,09</td>
#     </tr>
#     <tr>
#       <th id="T_39595_level0_row15" class="row_heading level0 row15" >Cartouches De Fusil De Chasse</th>
#       <td id="T_39595_row15_col0" class="data row15 col0" >0,01</td>
#       <td id="T_39595_row15_col1" class="data row15 col1" >0,01</td>
#     </tr>
#     <tr>
#       <th id="T_39595_level0_row16" class="row_heading level0 row16" >Mousse De Plastique Pour L'Isolation Thermique</th>
#       <td id="T_39595_row16_col0" class="data row16 col0" >0,10</td>
#       <td id="T_39595_row16_col1" class="data row16 col1" >0,10</td>
#     </tr>
#     <tr>
#       <th id="T_39595_level0_row17" class="row_heading level0 row17" >Déchets De Construction En Plastique</th>
#       <td id="T_39595_row17_col0" class="data row17 col0" >0,06</td>
#       <td id="T_39595_row17_col1" class="data row17 col1" >0,06</td>
#     </tr>
#     <tr>
#       <th id="T_39595_level0_row18" class="row_heading level0 row18" >Coton-Tige</th>
#       <td id="T_39595_row18_col0" class="data row18 col0" >0,12</td>
#       <td id="T_39595_row18_col1" class="data row18 col1" >0,12</td>
#     </tr>
#     <tr>
#       <th id="T_39595_level0_row19" class="row_heading level0 row19" >Couvercles En Plastique Bouteille:  G21, G22, G23, G24</th>
#       <td id="T_39595_row19_col0" class="data row19 col0" >0,11</td>
#       <td id="T_39595_row19_col1" class="data row19 col1" >0,11</td>
#     </tr>
#     <tr>
#       <th id="T_39595_level0_row20" class="row_heading level0 row20" >Fragments De Polystyrène Expansé: G76, G81, G82, G83</th>
#       <td id="T_39595_row20_col0" class="data row20 col0" >0,26</td>
#       <td id="T_39595_row20_col1" class="d

# %% [markdown]
# #### Alternate object groups
#
# If the column has other labeled values for object identification it can be used to aggregate results for each sample id. Here we consider `groupname, there is more than one object in a group. They represent use cases.
#
# ```python
# t = a_cumulative_report(w_df[w_df.code.isin(a_report.most_common.index)], feature_name='feature_type', object_column='groupname')
# translated_and_style_for_display(t, a_report.lang_maps[a_report.language], a_report.language, gradient=True)
# ```
# For example the different use cases are found at different densitiies depending on the feature type.

# %%
t = r_class.a_cumulative_report(w_df, feature_name='feature_type', object_column='groupname')
r_class.translated_and_style_for_display(t, a_report.lang_maps[a_report.language], a_report.language, gradient=True)
# Out:
# <style type="text/css">
# #T_96837 tr:nth-child(even) {
#   background-color: rgba(139, 69, 19, 0.08);
# }
# #T_96837 tr:nth-child(odd) {
#   background: #FFF;
# }
# #T_96837 tr {
#   font-size: 10px;
# }
# #T_96837 th:nth-child(1) {
#   background-color: #FFF;
#   font-size: 12px;
#   text-align: left;
# }
# #T_96837 td {
#   padding: 4px;
#   font-size: 12px;
# }
# #T_96837 caption {
#   caption-side: bottom;
#   font-size: 1em;
#   text-align: left;
# }
# #T_96837_row0_col0, #T_96837_row0_col1 {
#   background-color: rgba(203,203,203, .5);
#   color: black;
# }
# #T_96837_row1_col0, #T_96837_row1_col1 {
#   background-color: rgba(144,45,3, .5);
#   color: black;
# }
# #T_96837_row2_col0, #T_96837_row2_col1 {
#   background-color: rgba(244,115,30, .5);
#   color: black;
# }
# #T_96837_row3_col0, #T_96837_row3_col1 {
#   background-color: rgba(193,193,193, .5);
#   color: black;
# }
# #T_96837_row4_col0, #T_96837_row4_col1 {
#   background-color: rgba(208,208,208, .5);
#   color: black;
# }
# #T_96837_row5_col0, #T_96837_row5_col1 {
#   background-color: rgba(222,222,222, .5);
#   color: black;
# }
# #T_96837_row6_col0, #T_96837_row6_col1 {
#   background-color: rgba(253,176,110, .5);
#   color: black;
# }
# #T_96837_row7_col0, #T_96837_row7_col1 {
#   background-color: rgba(174,174,174, .5);
#   color: black;
# }
# #T_96837_row8_col0, #T_96837_row8_col1 {
#   background-color: rgba(253,224,195, .5);
#   color: black;
# }
# #T_96837_row9_col0, #T_96837_row9_col1 {
#   background-color: rgba(249,249,249, .5);
#   color: black;
# }
# #T_96837_row10_col0, #T_96837_row10_col1 {
#   background-color: rgba(170,170,170, .5);
#   color: black;
# }
# </style>
# <table id="T_96837">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_96837_level0_col0" class="col_heading level0 col0" >Lac</th>
#       <th id="T_96837_level0_col1" class="col_heading level0 col1" >Cumulé</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_96837_level0_row0" class="row_heading level0 row0" >Agriculture</th>
#       <td id="T_96837_row0_col0" class="data row0 col0" >0,14</td>
#       <td id="T_96837_row0_col1" class="data row0 col1" >0,14</td>
#     </tr>
#     <tr>
#       <th id="T_96837_level0_row1" class="row_heading level0 row1" >Nourriture Et Boissons</th>
#       <td id="T_96837_row1_col0" class="data row1 col0" >0,88</td>
#       <td id="T_96837_row1_col1" class="data row1 col1" >0,88</td>
#     </tr>
#     <tr>
#       <th id="T_96837_level0_row2" class="row_heading level0 row2" >Infrastructures</th>
#       <td id="T_96837_row2_col0" class="data row2 col0" >0,71</td>
#       <td id="T_96837_row2_col1" class="data row2 col1" >0,71</td>
#     </tr>
#     <tr>
#       <th id="T_96837_level0_row3" class="row_heading level0 row3" >Micro-Plastiques (< 5Mm)</th>
#       <td id="T_96837_row3_col0" class="data row3 col0" >0,16</td>
#       <td id="T_96837_row3_col1" class="data row3 col1" >0,16</td>
#     </tr>
#     <tr>
#       <th id="T_96837_level0_row4" class="row_heading level0 row4" >Emballage Non Alimentaire</th>
#       <td id="T_96837_row4_col0" class="data row4 col0" >0,13</td>
#       <td id="T_96837_row4_col1" class="data row4 col1" >0,13</td>
#     </tr>
#     <tr>
#       <th id="T_96837_level0_row5" class="row_heading level0 row5" >Articles Personnels</th>
#       <td id="T_96837_row5_col0" class="data row5 col0" >0,10</td>
#       <td id="T_96837_row5_col1" class="data row5 col1" >0,10</td>
#     </tr>
#     <tr>
#       <th id="T_96837_level0_row6" class="row_heading level0 row6" >Morceaux De Plastique</th>
#       <td id="T_96837_row6_col0" class="data row6 col0" >0,61</td>
#       <td id="T_96837_row6_col1" class="data row6 col1" >0,61</td>
#     </tr>
#     <tr>
#       <th id="T_96837_level0_row7" class="row_heading level0 row7" >Loisirs</th>
#       <td id="T_96837_row7_col0" class="data row7 col0" >0,19</td>
#       <td id="T_96837_row7_col1" class="data row7 col1" >0,19</td>
#     </tr>
#     <tr>
#       <th id="T_96837_level0_row8" class="row_heading level0 row8" >Tabac</th>
#       <td id="T_96837_row8_col0" class="data row8 col0" >0,52</td>
#       <td id="T_96837_row8_col1" class="data row8 col1" >0,52</td>
#     </tr>
#     <tr>
#       <th id="T_96837_level0_row9" class="row_heading level0 row9" >Non Classé</th>
#       <td id="T_96837_row9_col0" class="data row9 col0" >0,02</td>
#       <td id="T_96837_row9_col1" class="data row9 col1" >0,02</td>
#     </tr>
#     <tr>
#       <th id="T_96837_level0_row10" class="row_heading level0 row10" >Eaux Usées</th>
#       <td id="T_96837_row10_col0" class="data row10 col0" >0,20</td>
#       <td id="T_96837_row10_col1" class="data row10 col1" >0,20</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# #### By Survey area or `parent_boundary`
#
# There are two parent boundaries in the Valais, the _Alpes and Jura_ and the _Rhône_ river basin.

# %%
t = r_class.a_cumulative_report(w_df[w_df.code.isin(a_report.most_common.index)], feature_name='parent_boundary', object_column='code')

r_class.translated_and_style_for_display(t,a_report.lang_maps[a_report.language], a_report.language, gradient=True)
# Out:
# <style type="text/css">
# #T_96d27 tr:nth-child(even) {
#   background-color: rgba(139, 69, 19, 0.08);
# }
# #T_96d27 tr:nth-child(odd) {
#   background: #FFF;
# }
# #T_96d27 tr {
#   font-size: 10px;
# }
# #T_96d27 th:nth-child(1) {
#   background-color: #FFF;
#   font-size: 12px;
#   text-align: left;
# }
# #T_96d27 td {
#   padding: 4px;
#   font-size: 12px;
# }
# #T_96d27 caption {
#   caption-side: bottom;
#   font-size: 1em;
#   text-align: left;
# }
# #T_96d27_row0_col0, #T_96d27_row0_col1, #T_96d27_row15_col0, #T_96d27_row15_col1 {
#   background-color: rgba(252,252,252, .5);
#   color: black;
# }
# #T_96d27_row1_col0, #T_96d27_row1_col1, #T_96d27_row4_col0, #T_96d27_row4_col1, #T_96d27_row7_col0, #T_96d27_row7_col1, #T_96d27_row12_col0, #T_96d27_row12_col1 {
#   background-color: rgba(249,249,249, .5);
#   color: black;
# }
# #T_96d27_row2_col0, #T_96d27_row2_col1, #T_96d27_row3_col0, #T_96d27_row3_col1 {
#   background-color: rgba(255,255,255, .5);
#   color: black;
# }
# #T_96d27_row5_col0, #T_96d27_row5_col1, #T_96d27_row6_col0, #T_96d27_row6_col1, #T_96d27_row10_col0, #T_96d27_row10_col1 {
#   background-color: rgba(247,247,247, .5);
#   color: black;
# }
# #T_96d27_row8_col0, #T_96d27_row8_col1 {
#   background-color: rgba(254,239,224, .5);
#   color: black;
# }
# #T_96d27_row9_col0, #T_96d27_row9_col1 {
#   background-color: rgba(156,156,156, .5);
#   color: black;
# }
# #T_96d27_row11_col0, #T_96d27_row11_col1 {
#   background-color: rgba(248,248,248, .5);
#   color: black;
# }
# #T_96d27_row13_col0, #T_96d27_row13_col1 {
#   background-color: rgba(244,244,244, .5);
#   color: black;
# }
# #T_96d27_row14_col0, #T_96d27_row14_col1 {
#   background-color: rgba(226,226,226, .5);
#   color: black;
# }
# #T_96d27_row16_col0, #T_96d27_row16_col1 {
#   background-color: rgba(222,222,222, .5);
#   color: black;
# }
# #T_96d27_row17_col0, #T_96d27_row17_col1 {
#   background-color: rgba(240,240,240, .5);
#   color: black;
# }
# #T_96d27_row18_col0, #T_96d27_row18_col1 {
#   background-color: rgba(213,213,213, .5);
#   color: black;
# }
# #T_96d27_row19_col0, #T_96d27_row19_col1 {
#   background-color: rgba(218,218,218, .5);
#   color: black;
# }
# #T_96d27_row20_col0, #T_96d27_row20_col1 {
#   background-color: rgba(128,128,128, .5);
#   color: black;
# }
# #T_96d27_row21_col0, #T_96d27_row21_col1 {
#   background-color: rgba(253,176,110, .5);
#   color: black;
# }
# </style>
# <table id="T_96d27">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_96d27_level0_col0" class="col_heading level0 col0" >Rhône</th>
#       <th id="T_96d27_level0_col1" class="col_heading level0 col1" >Cumulé</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_96d27_level0_row0" class="row_heading level0 row0" >Emballage Fast Food</th>
#       <td id="T_96d27_row0_col0" class="data row0 col0" >0,01</td>
#       <td id="T_96d27_row0_col1" class="data row0 col1" >0,01</td>
#     </tr>
#     <tr>
#       <th id="T_96d27_level0_row1" class="row_heading level0 row1" >Médical Conteneurs/Tubes/ Emballages</th>
#       <td id="T_96d27_row1_col0" class="data row1 col0" >0,02</td>
#       <td id="T_96d27_row1_col1" class="data row1 col1" >0,02</td>
#     </tr>
#     <tr>
#       <th id="T_96d27_level0_row2" class="row_heading level0 row2" >Pellets Industriels (Gpi)</th>
#       <td id="T_96d27_row2_col0" class="data row2 col0" >0,00</td>
#       <td id="T_96d27_row2_col1" class="data row2 col1" >0,00</td>
#     </tr>
#     <tr>
#       <th id="T_96d27_level0_row3" class="row_heading level0 row3" >Polystyrène < 5Mm</th>
#       <td id="T_96d27_row3_col0" class="data row3 col0" >0,00</td>
#       <td id="T_96d27_row3_col1" class="data row3 col1" >0,00</td>
#     </tr>
#     <tr>
#       <th id="T_96d27_level0_row4" class="row_heading level0 row4" >Papier D'Emballage D'Aluminium</th>
#       <td id="T_96d27_row4_col0" class="data row4 col0" >0,02</td>
#       <td id="T_96d27_row4_col1" class="data row4 col1" >0,02</td>
#     </tr>
#     <tr>
#       <th id="T_96d27_level0_row5" class="row_heading level0 row5" >Bouchons De Bouteilles En Métal, Couvercles Et Tirettes</th>
#       <td id="T_96d27_row5_col0" class="data row5 col0" >0,03</td>
#       <td id="T_96d27_row5_col1" class="data row5 col1" >0,03</td>
#     </tr>
#     <tr>
#       <th id="T_96d27_level0_row6" class="row_heading level0 row6" >Verre Brisé</th>
#       <td id="T_96d27_row6_col0" class="data row6 col0" >0,03</td>
#       <td id="T_96d27_row6_col1" class="data row6 col1" >0,03</td>
#     </tr>
#     <tr>
#       <th id="T_96d27_level0_row7" class="row_heading level0 row7" >Tabac Emballages En Plastique</th>
#       <td id="T_96d27_row7_col0" class="data row7 col0" >0,02</td>
#       <td id="T_96d27_row7_col1" class="data row7 col1" >0,02</td>
#     </tr>
#     <tr>
#       <th id="T_96d27_level0_row8" class="row_heading level0 row8" >Mégots Et Filtres À Cigarettes</th>
#       <td id="T_96d27_row8_col0" class="data row8 col0" >0,47</td>
#       <td id="T_96d27_row8_col1" class="data row8 col1" >0,47</td>
#     </tr>
#     <tr>
#       <th id="T_96d27_level0_row9" class="row_heading level0 row9" >Emballages De Bonbons, De Snacks</th>
#       <td id="T_96d27_row9_col0" class="data row9 col0" >0,21</td>
#       <td id="T_96d27_row9_col1" class="data row9 col1" >0,21</td>
#     </tr>
#     <tr>
#       <th id="T_96d27_level0_row10" class="row_heading level0 row10" >Bâtonnets De Sucette</th>
#       <td id="T_96d27_row10_col0" class="data row10 col0" >0,03</td>
#       <td id="T_96d27_row10_col1" class="data row10 col1" >0,03</td>
#     </tr>
#     <tr>
#       <th id="T_96d27_level0_row11" class="row_heading level0 row11" >Jouets Et Faveurs De Fête</th>
#       <td id="T_96d27_row11_col0" class="data row11 col0" >0,03</td>
#       <td id="T_96d27_row11_col1" class="data row11 col1" >0,03</td>
#     </tr>
#     <tr>
#       <th id="T_96d27_level0_row12" class="row_heading level0 row12" >Gobelets, Couvercles, Mousse À Usage Unique Et Plastique Dur</th>
#       <td id="T_96d27_row12_col0" class="data row12 col0" >0,02</td>
#       <td id="T_96d27_row12_col1" class="data row12 col1" >0,02</td>
#     </tr>
#     <tr>
#       <th id="T_96d27_level0_row13" class="row_heading level0 row13" >Pailles Et Agitateurs</th>
#       <td id="T_96d27_row13_col0" class="data row13 col0" >0,04</td>
#       <td id="T_96d27_row13_col1" class="data row13 col1" >0,04</td>
#     </tr>
#     <tr>
#       <th id="T_96d27_level0_row14" class="row_heading level0 row14" >Bâche, Feuille Plastique Industrielle</th>
#       <td id="T_96d27_row14_col0" class="data row14 col0" >0,09</td>
#       <td id="T_96d27_row14_col1" class="data row14 col1" >0,09</td>
#     </tr>
#     <tr>
#       <th id="T_96d27_level0_row15" class="row_heading level0 row15" >Cartouches De Fusil De Chasse</th>
#       <td id="T_96d27_row15_col0" class="data row15 col0" >0,01</td>
#       <td id="T_96d27_row15_col1" class="data row15 col1" >0,01</td>
#     </tr>
#     <tr>
#       <th id="T_96d27_level0_row16" class="row_heading level0 row16" >Mousse De Plastique Pour L'Isolation Thermique</th>
#       <td id="T_96d27_row16_col0" class="data row16 col0" >0,10</td>
#       <td id="T_96d27_row16_col1" class="data row16 col1" >0,10</td>
#     </tr>
#     <tr>
#       <th id="T_96d27_level0_row17" class="row_heading level0 row17" >Déchets De Construction En Plastique</th>
#       <td id="T_96d27_row17_col0" class="data row17 col0" >0,06</td>
#       <td id="T_96d27_row17_col1" class="data row17 col1" >0,06</td>
#     </tr>
#     <tr>
#       <th id="T_96d27_level0_row18" class="row_heading level0 row18" >Coton-Tige</th>
#       <td id="T_96d27_row18_col0" class="data row18 col0" >0,12</td>
#       <td id="T_96d27_row18_col1" class="data row18 col1" >0,12</td>
#     </tr>
#     <tr>
#       <th id="T_96d27_level0_row19" class="row_heading level0 row19" >Couvercles En Plastique Bouteille:  G21, G22, G23, G24</th>
#       <td id="T_96d27_row19_col0" class="data row19 col0" >0,11</td>
#       <td id="T_96d27_row19_col1" class="data row19 col1" >0,11</td>
#     </tr>
#     <tr>
#       <th id="T_96d27_level0_row20" class="row_heading level0 row20" >Fragments De Polystyrène Expansé: G76, G81, G82, G83</th>
#       <td id="T_96d27_row20_col0" class="data row20 col0" >0,26</td>
#       <td id="T_96d27_row20_col1" class=

# %% [markdown]
# #### By feature name:
#
# There are three different features with samples: Tha Alpes, the Rhône river and Lake Geneva.

# %%
t = r_class.a_cumulative_report(w_df[w_df.code.isin(a_report.most_common.index)], feature_name='feature_name', object_column='code')
r_class.translated_and_style_for_display(t, a_report.lang_maps[a_report.language], a_report.language, gradient=True)
# Out:
# <style type="text/css">
# #T_6df86 tr:nth-child(even) {
#   background-color: rgba(139, 69, 19, 0.08);
# }
# #T_6df86 tr:nth-child(odd) {
#   background: #FFF;
# }
# #T_6df86 tr {
#   font-size: 10px;
# }
# #T_6df86 th:nth-child(1) {
#   background-color: #FFF;
#   font-size: 12px;
#   text-align: left;
# }
# #T_6df86 td {
#   padding: 4px;
#   font-size: 12px;
# }
# #T_6df86 caption {
#   caption-side: bottom;
#   font-size: 1em;
#   text-align: left;
# }
# #T_6df86_row0_col0, #T_6df86_row0_col1, #T_6df86_row15_col0, #T_6df86_row15_col1 {
#   background-color: rgba(252,252,252, .5);
#   color: black;
# }
# #T_6df86_row1_col0, #T_6df86_row1_col1, #T_6df86_row4_col0, #T_6df86_row4_col1, #T_6df86_row7_col0, #T_6df86_row7_col1, #T_6df86_row12_col0, #T_6df86_row12_col1 {
#   background-color: rgba(249,249,249, .5);
#   color: black;
# }
# #T_6df86_row2_col0, #T_6df86_row2_col1, #T_6df86_row3_col0, #T_6df86_row3_col1 {
#   background-color: rgba(255,255,255, .5);
#   color: black;
# }
# #T_6df86_row5_col0, #T_6df86_row5_col1, #T_6df86_row6_col0, #T_6df86_row6_col1, #T_6df86_row10_col0, #T_6df86_row10_col1 {
#   background-color: rgba(247,247,247, .5);
#   color: black;
# }
# #T_6df86_row8_col0, #T_6df86_row8_col1 {
#   background-color: rgba(254,239,224, .5);
#   color: black;
# }
# #T_6df86_row9_col0, #T_6df86_row9_col1 {
#   background-color: rgba(156,156,156, .5);
#   color: black;
# }
# #T_6df86_row11_col0, #T_6df86_row11_col1 {
#   background-color: rgba(248,248,248, .5);
#   color: black;
# }
# #T_6df86_row13_col0, #T_6df86_row13_col1 {
#   background-color: rgba(244,244,244, .5);
#   color: black;
# }
# #T_6df86_row14_col0, #T_6df86_row14_col1 {
#   background-color: rgba(226,226,226, .5);
#   color: black;
# }
# #T_6df86_row16_col0, #T_6df86_row16_col1 {
#   background-color: rgba(222,222,222, .5);
#   color: black;
# }
# #T_6df86_row17_col0, #T_6df86_row17_col1 {
#   background-color: rgba(240,240,240, .5);
#   color: black;
# }
# #T_6df86_row18_col0, #T_6df86_row18_col1 {
#   background-color: rgba(213,213,213, .5);
#   color: black;
# }
# #T_6df86_row19_col0, #T_6df86_row19_col1 {
#   background-color: rgba(218,218,218, .5);
#   color: black;
# }
# #T_6df86_row20_col0, #T_6df86_row20_col1 {
#   background-color: rgba(128,128,128, .5);
#   color: black;
# }
# #T_6df86_row21_col0, #T_6df86_row21_col1 {
#   background-color: rgba(253,176,110, .5);
#   color: black;
# }
# </style>
# <table id="T_6df86">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6df86_level0_col0" class="col_heading level0 col0" >Lac-Leman</th>
#       <th id="T_6df86_level0_col1" class="col_heading level0 col1" >Cumulé</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6df86_level0_row0" class="row_heading level0 row0" >Emballage Fast Food</th>
#       <td id="T_6df86_row0_col0" class="data row0 col0" >0,01</td>
#       <td id="T_6df86_row0_col1" class="data row0 col1" >0,01</td>
#     </tr>
#     <tr>
#       <th id="T_6df86_level0_row1" class="row_heading level0 row1" >Médical Conteneurs/Tubes/ Emballages</th>
#       <td id="T_6df86_row1_col0" class="data row1 col0" >0,02</td>
#       <td id="T_6df86_row1_col1" class="data row1 col1" >0,02</td>
#     </tr>
#     <tr>
#       <th id="T_6df86_level0_row2" class="row_heading level0 row2" >Pellets Industriels (Gpi)</th>
#       <td id="T_6df86_row2_col0" class="data row2 col0" >0,00</td>
#       <td id="T_6df86_row2_col1" class="data row2 col1" >0,00</td>
#     </tr>
#     <tr>
#       <th id="T_6df86_level0_row3" class="row_heading level0 row3" >Polystyrène < 5Mm</th>
#       <td id="T_6df86_row3_col0" class="data row3 col0" >0,00</td>
#       <td id="T_6df86_row3_col1" class="data row3 col1" >0,00</td>
#     </tr>
#     <tr>
#       <th id="T_6df86_level0_row4" class="row_heading level0 row4" >Papier D'Emballage D'Aluminium</th>
#       <td id="T_6df86_row4_col0" class="data row4 col0" >0,02</td>
#       <td id="T_6df86_row4_col1" class="data row4 col1" >0,02</td>
#     </tr>
#     <tr>
#       <th id="T_6df86_level0_row5" class="row_heading level0 row5" >Bouchons De Bouteilles En Métal, Couvercles Et Tirettes</th>
#       <td id="T_6df86_row5_col0" class="data row5 col0" >0,03</td>
#       <td id="T_6df86_row5_col1" class="data row5 col1" >0,03</td>
#     </tr>
#     <tr>
#       <th id="T_6df86_level0_row6" class="row_heading level0 row6" >Verre Brisé</th>
#       <td id="T_6df86_row6_col0" class="data row6 col0" >0,03</td>
#       <td id="T_6df86_row6_col1" class="data row6 col1" >0,03</td>
#     </tr>
#     <tr>
#       <th id="T_6df86_level0_row7" class="row_heading level0 row7" >Tabac Emballages En Plastique</th>
#       <td id="T_6df86_row7_col0" class="data row7 col0" >0,02</td>
#       <td id="T_6df86_row7_col1" class="data row7 col1" >0,02</td>
#     </tr>
#     <tr>
#       <th id="T_6df86_level0_row8" class="row_heading level0 row8" >Mégots Et Filtres À Cigarettes</th>
#       <td id="T_6df86_row8_col0" class="data row8 col0" >0,47</td>
#       <td id="T_6df86_row8_col1" class="data row8 col1" >0,47</td>
#     </tr>
#     <tr>
#       <th id="T_6df86_level0_row9" class="row_heading level0 row9" >Emballages De Bonbons, De Snacks</th>
#       <td id="T_6df86_row9_col0" class="data row9 col0" >0,21</td>
#       <td id="T_6df86_row9_col1" class="data row9 col1" >0,21</td>
#     </tr>
#     <tr>
#       <th id="T_6df86_level0_row10" class="row_heading level0 row10" >Bâtonnets De Sucette</th>
#       <td id="T_6df86_row10_col0" class="data row10 col0" >0,03</td>
#       <td id="T_6df86_row10_col1" class="data row10 col1" >0,03</td>
#     </tr>
#     <tr>
#       <th id="T_6df86_level0_row11" class="row_heading level0 row11" >Jouets Et Faveurs De Fête</th>
#       <td id="T_6df86_row11_col0" class="data row11 col0" >0,03</td>
#       <td id="T_6df86_row11_col1" class="data row11 col1" >0,03</td>
#     </tr>
#     <tr>
#       <th id="T_6df86_level0_row12" class="row_heading level0 row12" >Gobelets, Couvercles, Mousse À Usage Unique Et Plastique Dur</th>
#       <td id="T_6df86_row12_col0" class="data row12 col0" >0,02</td>
#       <td id="T_6df86_row12_col1" class="data row12 col1" >0,02</td>
#     </tr>
#     <tr>
#       <th id="T_6df86_level0_row13" class="row_heading level0 row13" >Pailles Et Agitateurs</th>
#       <td id="T_6df86_row13_col0" class="data row13 col0" >0,04</td>
#       <td id="T_6df86_row13_col1" class="data row13 col1" >0,04</td>
#     </tr>
#     <tr>
#       <th id="T_6df86_level0_row14" class="row_heading level0 row14" >Bâche, Feuille Plastique Industrielle</th>
#       <td id="T_6df86_row14_col0" class="data row14 col0" >0,09</td>
#       <td id="T_6df86_row14_col1" class="data row14 col1" >0,09</td>
#     </tr>
#     <tr>
#       <th id="T_6df86_level0_row15" class="row_heading level0 row15" >Cartouches De Fusil De Chasse</th>
#       <td id="T_6df86_row15_col0" class="data row15 col0" >0,01</td>
#       <td id="T_6df86_row15_col1" class="data row15 col1" >0,01</td>
#     </tr>
#     <tr>
#       <th id="T_6df86_level0_row16" class="row_heading level0 row16" >Mousse De Plastique Pour L'Isolation Thermique</th>
#       <td id="T_6df86_row16_col0" class="data row16 col0" >0,10</td>
#       <td id="T_6df86_row16_col1" class="data row16 col1" >0,10</td>
#     </tr>
#     <tr>
#       <th id="T_6df86_level0_row17" class="row_heading level0 row17" >Déchets De Construction En Plastique</th>
#       <td id="T_6df86_row17_col0" class="data row17 col0" >0,06</td>
#       <td id="T_6df86_row17_col1" class="data row17 col1" >0,06</td>
#     </tr>
#     <tr>
#       <th id="T_6df86_level0_row18" class="row_heading level0 row18" >Coton-Tige</th>
#       <td id="T_6df86_row18_col0" class="data row18 col0" >0,12</td>
#       <td id="T_6df86_row18_col1" class="data row18 col1" >0,12</td>
#     </tr>
#     <tr>
#       <th id="T_6df86_level0_row19" class="row_heading level0 row19" >Couvercles En Plastique Bouteille:  G21, G22, G23, G24</th>
#       <td id="T_6df86_row19_col0" class="data row19 col0" >0,11</td>
#       <td id="T_6df86_row19_col1" class="data row19 col1" >0,11</td>
#     </tr>
#     <tr>
#       <th id="T_6df86_level0_row20" class="row_heading level0 row20" >Fragments De Polystyrène Expansé: G76, G81, G82, G83</th>
#       <td id="T_6df86_row20_col0" class="data row20 col0" >0,26</td>
#       <td id="T_6df86_row20_col1" cl

# %% [markdown]
# #### By city:

# %%
t = r_class.a_cumulative_report(w_df[w_df.code.isin(a_report.most_common.index)], feature_name='city', object_column='code')
r_class.translated_and_style_for_display(t, a_report.lang_maps[a_report.language], a_report.language, gradient=True)
# Out:
# <style type="text/css">
# #T_d77d2 tr:nth-child(even) {
#   background-color: rgba(139, 69, 19, 0.08);
# }
# #T_d77d2 tr:nth-child(odd) {
#   background: #FFF;
# }
# #T_d77d2 tr {
#   font-size: 10px;
# }
# #T_d77d2 th:nth-child(1) {
#   background-color: #FFF;
#   font-size: 12px;
#   text-align: left;
# }
# #T_d77d2 td {
#   padding: 4px;
#   font-size: 12px;
# }
# #T_d77d2 caption {
#   caption-side: bottom;
#   font-size: 1em;
#   text-align: left;
# }
# #T_d77d2_row0_col0, #T_d77d2_row0_col1, #T_d77d2_row0_col2, #T_d77d2_row0_col3, #T_d77d2_row0_col8, #T_d77d2_row0_col12, #T_d77d2_row1_col2, #T_d77d2_row1_col3, #T_d77d2_row2_col3, #T_d77d2_row2_col5, #T_d77d2_row2_col7, #T_d77d2_row2_col9, #T_d77d2_row2_col10, #T_d77d2_row2_col11, #T_d77d2_row2_col13, #T_d77d2_row3_col0, #T_d77d2_row3_col1, #T_d77d2_row3_col2, #T_d77d2_row3_col3, #T_d77d2_row3_col5, #T_d77d2_row3_col7, #T_d77d2_row3_col8, #T_d77d2_row3_col11, #T_d77d2_row3_col12, #T_d77d2_row3_col13, #T_d77d2_row4_col3, #T_d77d2_row4_col4, #T_d77d2_row4_col5, #T_d77d2_row4_col7, #T_d77d2_row4_col9, #T_d77d2_row4_col12, #T_d77d2_row5_col1, #T_d77d2_row5_col12, #T_d77d2_row6_col5, #T_d77d2_row6_col8, #T_d77d2_row7_col1, #T_d77d2_row7_col2, #T_d77d2_row7_col3, #T_d77d2_row7_col6, #T_d77d2_row7_col9, #T_d77d2_row10_col2, #T_d77d2_row10_col3, #T_d77d2_row10_col8, #T_d77d2_row11_col0, #T_d77d2_row11_col2, #T_d77d2_row12_col0, #T_d77d2_row12_col2, #T_d77d2_row12_col3, #T_d77d2_row12_col9, #T_d77d2_row12_col11, #T_d77d2_row14_col1, #T_d77d2_row14_col2, #T_d77d2_row14_col11, #T_d77d2_row15_col0, #T_d77d2_row15_col2, #T_d77d2_row15_col3, #T_d77d2_row15_col8, #T_d77d2_row15_col9, #T_d77d2_row16_col9, #T_d77d2_row17_col0, #T_d77d2_row17_col2, #T_d77d2_row17_col3 {
#   background-color: rgba(255,255,255, .5);
#   color: black;
# }
# #T_d77d2_row0_col4, #T_d77d2_row1_col6, #T_d77d2_row14_col6 {
#   background-color: rgba(121,121,121, .5);
#   color: black;
# }
# #T_d77d2_row0_col5, #T_d77d2_row0_col9, #T_d77d2_row1_col9, #T_d77d2_row2_col4, #T_d77d2_row4_col11, #T_d77d2_row5_col3, #T_d77d2_row5_col4, #T_d77d2_row5_col7, #T_d77d2_row5_col11, #T_d77d2_row5_col13, #T_d77d2_row6_col4, #T_d77d2_row6_col13, #T_d77d2_row7_col12, #T_d77d2_row10_col7, #T_d77d2_row10_col13, #T_d77d2_row11_col12, #T_d77d2_row13_col3, #T_d77d2_row19_col2 {
#   background-color: rgba(247,247,247, .5);
#   color: black;
# }
# #T_d77d2_row0_col6, #T_d77d2_row4_col10, #T_d77d2_row5_col5, #T_d77d2_row5_col6, #T_d77d2_row5_col10, #T_d77d2_row10_col6, #T_d77d2_row10_col9, #T_d77d2_row19_col9 {
#   background-color: rgba(241,241,241, .5);
#   color: black;
# }
# #T_d77d2_row0_col7, #T_d77d2_row2_col1, #T_d77d2_row4_col1, #T_d77d2_row5_col9, #T_d77d2_row6_col7, #T_d77d2_row7_col8, #T_d77d2_row7_col10, #T_d77d2_row10_col1, #T_d77d2_row11_col6, #T_d77d2_row12_col1, #T_d77d2_row12_col6, #T_d77d2_row13_col9, #T_d77d2_row13_col13, #T_d77d2_row15_col6, #T_d77d2_row16_col12, #T_d77d2_row17_col7, #T_d77d2_row17_col8 {
#   background-color: rgba(244,244,244, .5);
#   color: black;
# }
# #T_d77d2_row0_col10, #T_d77d2_row1_col7, #T_d77d2_row1_col11, #T_d77d2_row1_col12, #T_d77d2_row1_col13, #T_d77d2_row2_col12, #T_d77d2_row3_col6, #T_d77d2_row4_col8, #T_d77d2_row4_col13, #T_d77d2_row5_col8, #T_d77d2_row7_col13, #T_d77d2_row10_col12, #T_d77d2_row11_col3, #T_d77d2_row11_col7, #T_d77d2_row11_col8, #T_d77d2_row11_col9, #T_d77d2_row12_col8, #T_d77d2_row12_col12, #T_d77d2_row12_col13, #T_d77d2_row13_col8, #T_d77d2_row15_col7, #T_d77d2_row15_col12, #T_d77d2_row18_col2, #T_d77d2_row20_col12 {
#   background-color: rgba(249,249,249, .5);
#   color: black;
# }
# #T_d77d2_row0_col11, #T_d77d2_row4_col2, #T_d77d2_row6_col11, #T_d77d2_row11_col13, #T_d77d2_row15_col10, #T_d77d2_row15_col11, #T_d77d2_row16_col10 {
#   background-color: rgba(248,248,248, .5);
#   color: black;
# }
# #T_d77d2_row0_col13, #T_d77d2_row1_col8, #T_d77d2_row6_col12, #T_d77d2_row7_col7, #T_d77d2_row7_col11, #T_d77d2_row9_col9, #T_d77d2_row11_col11, #T_d77d2_row12_col7, #T_d77d2_row12_col10, #T_d77d2_row13_col2, #T_d77d2_row13_col7, #T_d77d2_row13_col11, #T_d77d2_row15_col13, #T_d77d2_row16_col2, #T_d77d2_row20_col2 {
#   background-color: rgba(252,252,252, .5);
#   color: black;
# }
# #T_d77d2_row1_col0 {
#   background-color: rgba(167,167,167, .5);
#   color: black;
# }
# #T_d77d2_row1_col1, #T_d77d2_row1_col5, #T_d77d2_row6_col9, #T_d77d2_row7_col5, #T_d77d2_row9_col1, #T_d77d2_row9_col11, #T_d77d2_row11_col5, #T_d77d2_row14_col7, #T_d77d2_row19_col7 {
#   background-color: rgba(230,230,230, .5);
#   color: black;
# }
# #T_d77d2_row1_col4, #T_d77d2_row9_col2, #T_d77d2_row17_col6 {
#   background-color: rgba(198,198,198, .5);
#   color: black;
# }
# #T_d77d2_row1_col10, #T_d77d2_row2_col2 {
#   background-color: rgba(245,245,245, .5);
#   color: black;
# }
# #T_d77d2_row2_col0 {
#   background-color: rgba(253,220,187, .5);
#   color: black;
# }
# #T_d77d2_row2_col6 {
#   background-color: rgba(251,137,56, .5);
#   color: black;
# }
# #T_d77d2_row2_col8, #T_d77d2_row16_col4 {
#   background-color: rgba(253,197,144, .5);
#   color: black;
# }
# #T_d77d2_row3_col4, #T_d77d2_row16_col3 {
#   background-color: rgba(181,181,181, .5);
#   color: black;
# }
# #T_d77d2_row3_col9 {
#   background-color: rgba(174,174,174, .5);
#   color: black;
# }
# #T_d77d2_row3_col10, #T_d77d2_row20_col13 {
#   background-color: rgba(128,128,128, .5);
#   color: black;
# }
# #T_d77d2_row4_col0, #T_d77d2_row8_col4, #T_d77d2_row17_col5, #T_d77d2_row19_col8, #T_d77d2_row19_col11 {
#   background-color: rgba(208,208,208, .5);
#   color: black;
# }
# #T_d77d2_row4_col6, #T_d77d2_row8_col11, #T_d77d2_row9_col12, #T_d77d2_row10_col0, #T_d77d2_row13_col5, #T_d77d2_row14_col0, #T_d77d2_row14_col9, #T_d77d2_row15_col5 {
#   background-color: rgba(188,188,188, .5);
#   color: black;
# }
# #T_d77d2_row5_col0, #T_d77d2_row9_col7, #T_d77d2_row14_col10, #T_d77d2_row16_col7, #T_d77d2_row16_col11, #T_d77d2_row17_col12, #T_d77d2_row18_col8, #T_d77d2_row18_col9, #T_d77d2_row18_col13, #T_d77d2_row19_col12 {
#   background-color: rgba(213,213,213, .5);
#   color: black;
# }
# #T_d77d2_row5_col2, #T_d77d2_row7_col0, #T_d77d2_row10_col10, #T_d77d2_row14_col3, #T_d77d2_row14_col12, #T_d77d2_row18_col7, #T_d77d2_row18_col11 {
#   background-color: rgba(234,234,234, .5);
#   color: black;
# }
# #T_d77d2_row6_col0, #T_d77d2_row19_col6 {
#   background-color: rgba(32,32,32, .5);
#   color: black;
# }
# #T_d77d2_row6_col1, #T_d77d2_row12_col4 {
#   background-color: rgba(160,160,160, .5);
#   color: black;
# }
# #T_d77d2_row6_col2, #T_d77d2_row11_col10 {
#   background-color: rgba(251,251,251, .5);
#   color: black;
# }
# #T_d77d2_row6_col3, #T_d77d2_row20_col3 {
#   background-color: rgba(109,109,109, .5);
#   color: black;
# }
# #T_d77d2_row6_col6 {
#   background-color: rgba(13,13,13, .5);
#   color: black;
# }
# #T_d77d2_row6_col10, #T_d77d2_row9_col3, #T_d77d2_row14_col13, #T_d77d2_row16_col5, #T_d77d2_row17_col10, #T_d77d2_row19_col3 {
#   background-color: rgba(226,226,226, .5);
#   color: black;
# }
# #T_d77d2_row7_col4, #T_d77d2_row9_col8, #T_d77d2_row13_col4, #T_d77d2_row21_col11 {
#   background-color: rgba(193,193,193, .5);
#   color: black;
# }
# #T_d77d2_row8_col0, #T_d77d2_row8_col3, #T_d77d2_row8_col9, #T_d77d2_row8_col10, #T_d77d2_row14_col4, #T_d77d2_row18_col4, #T_d77d2_row19_col4, #T_d77d2_row20_col0, #T_d77d2_row20_col4, #T_d77d2_row20_col6, #T_d77d2_row21_col0, #T_d77d2_row21_col1, #T_d77d2_row21_col4, #T_d77d2_row21_col5, #T_d77d2_row21_col6 {
#   background-color: rgba(127,39,4, .5);
#   color: black;
# }
# #T_d77d2_row8_col1 {
#   background-color: rgba(83,83,83, .5);
#   color: black;
# }
# #T_d77d2_row8_col2 {
#   background-color: rgba(215,215,215, .5);
#   color: black;
# }
# #T_d77d2_row8_col5 {
#   background-color: rgba(98,98,98, .5);
#   color: black;
# }
# #T_d77d2_row8_col6 {
#   background-color: rgba(154,49,3, .5);
#   color: black;
# }
# #T_d77d2_row8_col7 {
#   background-color: rgba(71,71,71, .5);
#   color: black;
# }
# #T_d77d2_row8_col8 {
#   background-color: rgba(228,88,9, .5);
#   color: black;
# }
# #T_d77d2_row8_col12, #T_d77d2_row16_col0 {
#   background-color: rgba(48,48,48, .5);
#   color: black;
# }
# #T_d77d2_row8_col13 {
#   background-color: rgba(254,239,224, .5);
#   color: black;
# }
# #T_d77d2_row9_col0 {
#   background-color: rgba(254

# %% [markdown]
# ## Retrieving properties
#
# There are 318'478 rows in the survey data. We can test the sorting and grouping functions by running a report class on all possible combinations of the features of interest. The test should produce the set of arguments that define the survey locations and surveys that define the boundaries of a report.
#
# ```python
# some_features = ['feature_type', 'parent_boundary', 'feature_name', 'canton', 'city']
#
# def produce_reports_for_testing(survey_data, some_features):
#     reports = {}
#     for a_feature in some_features:
#         labels = survey_data[a_feature].unique()
#         label_reports = {}
#         for label in labels:
#             start_date = survey_data[survey_data[a_feature] == label]['date'].min()
#             end_date = survey_data[survey_data[a_feature] == label]['date'].max()
#
#             boundaries = {a_feature:label, 'language':'fr', 'start_date':start_date, 'end_date':end_date}
#             top_label, language, w_df, w_di = report_data(boundaries, survey_data.copy())
#             a_report = ReportClass(w_df, w_di, boundaries, top_label, 'fr', c_l)
#             label_reports.update({label:a_report.features})
#         reports.update({a_feature:label_reports})
#     return reports
#
# t = produce_reports_for_testing(survey_data, some_features)
#
# t['canton']['Valais']
# ```

# %%
some_features = ['feature_type', 'parent_boundary', 'feature_name', 'canton', 'city']

def produce_reports_for_testing(survey_data, some_features):
    reports = {}
    for a_feature in some_features:
        labels = survey_data[a_feature].unique()
        label_reports = {}
        for label in labels:
            start_date = survey_data[survey_data[a_feature] == label]['date'].min()
            end_date = survey_data[survey_data[a_feature] == label]['date'].max()
            
            boundaries = {a_feature:label, 'language':'fr', 'start_date':start_date, 'end_date':end_date}
            top_label, language, w_df, w_di = r_class.report_data(boundaries, survey_data.copy(), beaches, codes)
            a_report = r_class.ReportClass(w_df, boundaries, top_label, 'fr', c_l)
            label_reports.update({label:a_report.features})
        reports.update({a_feature:label_reports})
    return reports
   
t = produce_reports_for_testing(survey_data, some_features)

# %%
t['canton']['Valais']
# Out:
# {'parent_boundary': array(['les-alpes', 'rhone'], dtype=object),
#  'feature_type': array(['p', 'l', 'r'], dtype=object),
#  'feature_name': array(['alpes-valaisannes', 'lac-leman', 'rhone'], dtype=object),
#  'city': array(['Nendaz', 'Lens', 'Val de Bagnes', 'Troistorrents', 'Riddes',
#         "Val-d'Illiez", 'Saint-Gingolph', 'Sion', 'Leuk', 'Salgesch'],
#        dtype=object),
#  'samples': array(["('clean-up-tour-veysonnaz', '2021-07-03')",
#         "('clean-up-tour-crans-montana', '2021-06-12')",
#         "('clean-up-tour-verbier', '2021-06-13')",
#         "('clean-up-tour-nendaz', '2021-07-04')",
#         "('clean-up-tour-morgins', '2021-06-05')",
#         "('clean-up-tour-la-tzoumaz', '2021-05-22')",
#         "('clean-up-tour-les-crosets', '2021-06-06')",
#         "('grand-clos', '2021-03-09')", "('grand-clos', '2020-08-06')",
#         "('grand-clos', '2016-09-21')", "('grand-clos', '2017-10-22')",
#         "('grand-clos', '2020-07-07')", "('grand-clos', '2020-10-06')",
#         "('grand-clos', '2020-12-08')", "('grand-clos', '2021-04-10')",
#         "('grand-clos', '2020-05-07')", "('grand-clos', '2020-06-09')",
#         "('les-glariers', '2020-12-01')", "('grand-clos', '2020-09-08')",
#         "('les-vieux-ronquoz', '2020-10-15')",
#         "('leuk-mattenstrasse', '2021-02-14')",
#         "('tschilljus', '2020-11-12')", "('grand-clos', '2021-02-09')",
#         "('grand-clos', '2021-01-07')"], dtype=object)}

# %% [markdown]
# The properties should contain the arguments for cities in the example report

# %%
t['city']['Saint-Gingolph']
# Out:
# {'parent_boundary': array(['rhone'], dtype=object),
#  'feature_name': array(['lac-leman'], dtype=object),
#  'feature_type': array(['l'], dtype=object),
#  'samples': array(["('grand-clos', '2021-03-09')", "('grand-clos', '2020-08-06')",
#         "('grand-clos', '2016-09-21')", "('grand-clos', '2017-10-22')",
#         "('grand-clos', '2020-07-07')", "('grand-clos', '2020-10-06')",
#         "('grand-clos', '2020-12-08')", "('grand-clos', '2021-04-10')",
#         "('grand-clos', '2020-05-07')", "('grand-clos', '2020-06-09')",
#         "('grand-clos', '2020-09-08')", "('grand-clos', '2021-02-09')",
#         "('grand-clos', '2021-01-07')"], dtype=object)}

# %% [markdown]
# ## Unit tests
#
# ### Combining codes using parent groups

# %%
import unittest
class TestUseGfragsGfoamsGcaps(unittest.TestCase):

    def test_use_gfrags_gfoams_gcaps(self):
        # Sample data and code mappings
        data = pd.DataFrame({'code': ['A', 'B', 'C', 'D', 'E', 'F'],
                             'sample_id': [1, 2, 1, 2, 1, 1],
                             'density': [1.5, 0.5, 1.5, 0.5, 1.5, 1],
                             'quantity': [2, 1, 2, 1, 2, 1]})
        codes = pd.DataFrame({'parent_code': ['Gfoams', 'Gfrags', 'Gcaps','Gfoams', 'Gcaps', 'F'],
                              'code': ['A', 'B', 'C', 'D', 'E', 'F']})
        codes.set_index('code', inplace=True)
        # Expected result
        expected_result = pd.DataFrame(
            {'code': {0: 'Gfoams', 1: 'Gfrags', 2: 'Gcaps', 3: 'Gfoams',  4: 'Gcaps',  5: 'F'},
             'sample_id': {0: 1, 1: 2, 2: 1, 3: 2, 4: 1, 5: 1},
             'density': {0: 1.5, 1: 0.5, 2: 1.5, 3: 0.5, 4: 1.5, 5: 1.0},
             'quantity': {0: 2, 1: 1, 2: 2, 3: 1, 4: 2, 5: 1}}
        )

        # Call the function
        updated_data = r_class.use_gfrags_gfoams_gcaps(data, codes)

        # Check if the result matches the expected result
        pd.testing.assert_frame_equal(updated_data, expected_result)

test_suite = unittest.TestLoader().loadTestsFromTestCase(TestUseGfragsGfoamsGcaps)
test_runner = unittest.TextTestRunner(verbosity=3)
test_result = test_runner.run(test_suite)
# Out:
# test_use_gfrags_gfoams_gcaps (__main__.TestUseGfragsGfoamsGcaps) ... ok
#
# ----------------------------------------------------------------------
# Ran 1 test in 0.004s
#
# OK

# %% [markdown]
# ### Aggregating values

# %%
class TestAggregateDataFrame(unittest.TestCase):

    def test_aggregate_dataframe(self):
        # Sample data
        data = pd.DataFrame({'code': ['A', 'B', 'C', 'D', 'E', 'F'],
                             'sample_id': [1, 2, 1, 2, 1, 1],
                             'density': [1.5, 0.5, 1.5, 0.5, 1.5, 1],
                             'quantity': [2, 1, 2, 1, 2, 1],
                             'prop a': ['s1', 's2','s1','s1','s2', 's3'],
                             'prop b': ['x' ,'x', 'z','z','z', 'q']})
        group_by_columns = ['sample_id','prop a']
        aggregation_functions = {'quantity': 'sum','density': 'median'}

        # Expected result
        expected_result = pd.DataFrame({
            'sample_id': {0: 1, 1: 1, 2: 1, 3: 2, 4: 2},
            'prop a': {0: 's1', 1: 's2', 2: 's3', 3: 's1', 4: 's2'},
            'quantity': {0: 4, 1: 2, 2: 1, 3: 1, 4: 1},
            'density': {0: 1.5, 1: 1.5, 2: 1.0, 3: 0.5, 4: 0.5}})

        # Call the function
        result = r_class.aggregate_dataframe(data, groupby_columns=group_by_columns, aggregation_functions=aggregation_functions)

        # Check if the result matches the expected result
        pd.testing.assert_frame_equal(result, expected_result)

test_suite = unittest.TestLoader().loadTestsFromTestCase(TestAggregateDataFrame)
test_runner = unittest.TextTestRunner(verbosity=3)
test_result = test_runner.run(test_suite)
# Out:
# test_aggregate_dataframe (__main__.TestAggregateDataFrame) ... ok
#
# ----------------------------------------------------------------------
# Ran 1 test in 0.004s
#
# OK

# %% [markdown]
# ### Calculating rate per unit

# %%
class TestCalculateRatePerUnit(unittest.TestCase):

    def test_calculate_rate_per_unit(self):
        # Sample data
        data = pd.DataFrame({
            'sample': [1, 2, 3, 4, 5, 6],
            'object': ['A', 'B', 'A', 'A', 'B', 'B'],
            'quantity': [10, 20, 30, 40, 50, 60],
            'pcs_m': [1,1,2,1, 2, 2],
        })

        # Objects to check
        column_of_interest = 'object'
        objects_to_check = ['A', 'B']
        groupby_columns = ['object']
        
        # Aggregation functions
        aggregation_methods = {
            'quantity': 'sum',
            'pcs_m': 'median'
        }
        
        # Expected result
        expected_result = pd.DataFrame({
            
            'pcs_m': {'A': 1.0, 'B': 2.0},
            'quantity': {'A': 80, 'B': 130},
            'label': {'A': 'all', 'B': 'all'}})
        
        # Call the function
        result = r_class.calculate_rate_per_unit(data, objects_to_check,column_of_interest=column_of_interest, groupby_columns=groupby_columns)
        result.index.name = None

        # Check if the result matches the expected result
        pd.testing.assert_frame_equal(result, expected_result)
test_suite = unittest.TestLoader().loadTestsFromTestCase(TestCalculateRatePerUnit)
test_runner = unittest.TextTestRunner(verbosity=3)
test_result = test_runner.run(test_suite)
# Out:
# test_calculate_rate_per_unit (__main__.TestCalculateRatePerUnit) ... ok
#
# ----------------------------------------------------------------------
# Ran 1 test in 0.006s
#
# OK

# %% [markdown]
# ### Cumulative rate per unit

# %%
class TestRatePerUnitCumulative(unittest.TestCase):

    def test_rate_per_unit_cumulative(self):
        # Sample data
        data = pd.DataFrame({
            'Region': ['A', 'A', 'B', 'B', 'A', 'B'],
            'Year': [2019, 2019, 2020, 2020, 2021, 2021],
            'Objects': ['X', 'Y', 'X', 'Y', 'Y', 'X'],
            'Value': [10, 20, 30, 40, 50, 60],
            'Count': [1, 1, 1, 1, 1, 1]
        })

        # Parameters
        groupby_columns = ['Region', 'Year']
        object_labels = ['Objects']
        objects = ['A', 'B']
        agg_methods = {'Value': 'sum', 'Count': 'count'}

        # Expected result
        expected_result = pd.DataFrame({
            'Region': ['A', 'B', 'A', 'B'],
            'Year': [2019, 2020, 2021, 2021],
            'Object A': ['A', 'B', 'A', 'A'],
            'Object B': ['Y', 'X', 'X', 'Y'],
            'Value': [30, 70, 110, 110],
            'Count': [2, 2, 1, 1]
        })

        # Call the function
        result = rate_per_unit_cumulative(data, groupby_columns, object_labels, objects, agg_methods)

        # Check if the result matches the expected result
        pd.testing.assert_frame_equal(result, expected_result)

# %%
data = pd.DataFrame({
            'Region': ['A', 'A', 'B', 'B', 'A', 'B'],
            'Year': [2019, 2019, 2020, 2020, 2021, 2021],
            'Objects': ['X', 'Y', 'X', 'Y', 'Y', 'X'],
            'Value': [10, 20, 30, 40, 50, 60],
            'Count': [1, 1, 1, 1, 1, 1]
        })

# Parameters
groupby_columns = ['Region', 'Year', 'Objects']
object_labels = ['Objects']
objects = ['X', 'B']
agg_methods = {'Value': 'sum', 'Count': 'count'}


# # Parameters
# groupby_columns = ['Region', 'Year']
# object_labels = ['Objects']
# objects = ['X', 'B']
# agg_methods = {'Value': 'sum', 'Count': 'count'}

a = r_class.aggregate_dataframe(data, groupby_columns, agg_methods)

b = r_class.calculate_rate_per_unit(a, objects_to_check=objects, column_of_interest='Objects', groupby_columns=groupby_columns, method= agg_methods)

# %%
# %watermark -a hammerdirt-analyst -co --iversions
# Out:
# Author: hammerdirt-analyst
#
# conda environment: cantonal_report
#
# pandas    : 2.0.3
# numpy     : 1.25.2
# matplotlib: 3.7.1
